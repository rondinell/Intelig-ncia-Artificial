# %% [markdown]
# <a href="https://colab.research.google.com/github/rondinell/Intelig-ncia-Artificial/blob/main/artigo14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ====================================================================
# Parte 1: INSTALAÇÃO E IMPORTAÇÕES
# ====================================================================
print("Instalando e importando bibliotecas...")
# !pip install yfinance mplfinance --quiet # Removendo biblioteca  ta para no futuro calcular de forma manual

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
from datetime import date
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Rescaling, LSTM, concatenate
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping

print("Bibliotecas carregadas com sucesso!")


# ====================================================================
# Parte 2: CONFIGURAÇÕES GLOBAIS
# ====================================================================
print("\nDefinindo configurações globais...")
TICKER = 'VALE3.SA'
START_DATE = '2015-01-01'
END_DATE = date.today().strftime("%Y-%m-%d")
SEQ_LENGTH = 60
FUTURE_DAYS = 5
THRESHOLD = 0.03
IMG_SIZE = 128
BATCH_SIZE = 32
EPOCHS = 40
BASE_DIR = '/content/stock_data_hybrid'

if os.path.exists(BASE_DIR):
    shutil.rmtree(BASE_DIR)
os.makedirs(BASE_DIR, exist_ok=True)
print("Configurações definidas e pastas criadas.")


# ====================================================================
# Parte 3: DOWNLOAD E CÁLCULO MANUAL DE INDICADORES (Using Pandas Series)
# ====================================================================
print(f"\nBaixando dados históricos para {TICKER}...")
data = yf.download(TICKER, start=START_DATE, end=END_DATE, auto_adjust=True, progress=False)
data.dropna(inplace=True)

print("Calculating technical indicators manually using Pandas Series...")

# Calculate Bollinger Bands directly on pandas Series
window = 20
data['volatility_bbm'] = data['Close'].rolling(window=window).mean()
data['volatility_bbh'] = data['Close'].rolling(window=window).mean() + data['Close'].rolling(window=window).std() * 2
data['volatility_bbl'] = data['Close'].rolling(window=window).mean() - data['Close'].rolling(window=window).std() * 2

# Calculate RSI directly on pandas Series using EMA
window_rsi = 14
delta = data['Close'].diff()
gain = delta.where(delta > 0, 0)
loss = -delta.where(delta < 0, 0)

avg_gain = gain.ewm(com=window_rsi - 1, adjust=False).mean()
avg_loss = loss.ewm(com=window_rsi - 1, adjust=False).mean()

# Avoid division by zero and handle potential inf values
rs = avg_gain / avg_loss
rs = rs.replace([np.inf, -np.inf], np.nan).fillna(0) # Replace inf with nan, then fill nan with 0

data['momentum_rsi'] = 100 - (100 / (1 + rs))


data.dropna(inplace=True)
print(f"{len(data)} days of data processed with indicators.")


# ====================================================================
# Parte 4: GERAÇÃO DAS IMAGENS E ALINHAMENTO DOS DADOS (CORRIGIDO)
# ====================================================================
print("\nGerando imagens e alinhando dados para o modelo híbrido...")

features_lstm = ['Close', 'Volume', 'volatility_bbh', 'volatility_bbl', 'volatility_bbm', 'momentum_rsi']
# O scaler é o mesmo, não precisa mudar
scaler = MinMaxScaler(feature_range=(0, 1)) # Moved scaler definition here
# data[features_lstm] = scaler.fit_transform(data[features_lstm])

# Criamos um novo dataframe para os dados normalizados para não afetar os cálculos de rótulo
data_normalized = data.copy()
data_normalized[features_lstm] = scaler.fit_transform(data[features_lstm])


image_paths, lstm_sequences, labels = [], [], []
class_names = ['ALTA', 'BAIXA', 'NEUTRA']
class_map = {name: i for i, name in enumerate(class_names)}

for i in range(len(data) - SEQ_LENGTH - FUTURE_DAYS):
    # --- Define o Rótulo (usando os dados originais, não normalizados) ---
    preco_final_janela = data['Close'].iloc[i + SEQ_LENGTH - 1]
    preco_futuro = data['Close'].iloc[i + SEQ_LENGTH + FUTURE_DAYS - 1]

    label_str = 'NEUTRA'
    # AJUSTE 1: A comparação agora é feita diretamente com os números, usando .iloc[0]
    if preco_futuro.iloc[0] > preco_final_janela.iloc[0] * (1 + THRESHOLD):
        label_str = 'ALTA'
    elif preco_futuro.iloc[0] < preco_final_janela.iloc[0] * (1 - THRESHOLD):
        label_str = 'BAIXA'
    labels.append(class_map[label_str])

    # --- Gera e Salva a Imagem (usando os dados normalizados) ---
    dados_janela_normalizados = data_normalized.iloc[i : i + SEQ_LENGTH] # Usar dados normalizados para a imagem/LSTM
    nome_arquivo = f"img_{i}.png"
    caminho_completo = os.path.join(BASE_DIR, nome_arquivo)

    fig, ax = plt.subplots(3, 1, figsize=(IMG_SIZE/100, IMG_SIZE/100), dpi=100, gridspec_kw={'height_ratios': [2, 1, 1]})
    ax[0].plot(dados_janela_normalizados['Close'].values, color='black')
    ax[0].plot(dados_janela_normalizados['volatility_bbh'].values, color='blue', alpha=0.5)
    ax[0].plot(dados_janela_normalizados['volatility_bbl'].values, color='blue', alpha=0.5)
    ax[1].plot(dados_janela_normalizados['momentum_rsi'].values, color='purple')
    ax[2].bar(range(len(dados_janela_normalizados)), dados_janela_normalizados['Volume'].values.flatten(), color='gray')
    for axis in ax: axis.axis('off')
    plt.subplots_adjust(left=0, right=1, top=1, bottom=0, hspace=0.01)
    fig.savefig(caminho_completo, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # --- Guarda os dados alinhados (usando os dados normalizados) ---
    image_paths.append(caminho_completo)
    lstm_sequences.append(dados_janela_normalizados[features_lstm].values)

# --- Conversão e Divisão dos Dados ---
image_paths = np.array(image_paths)
lstm_sequences = np.array(lstm_sequences)
# AJUSTE 2: Mude para np.int32 para que o Keras aceite os rótulos!
labels = np.array(labels, dtype=np.int32)

print(f"Total de {len(labels)} exemplos gerados e alinhados.")

# O restante do código de divisão de dados permanece o mesmo
img_train_paths, img_val_paths, X_train_lstm, X_val_lstm, y_train, y_val = train_test_split(
    image_paths, lstm_sequences, labels, test_size=0.2, random_state=42, stratify=labels
)
print(f"Dados divididos em {len(y_train)} para treino e {len(y_val)} para validação.")


# ====================================================================
# Parte 5: CONSTRUÇÃO DO MODELO HÍBRIDO (API FUNCIONAL)
# ====================================================================
print("\nConstruindo o Cérebro Híbrido (CNN + LSTM)...")

input_cnn = Input(shape=(IMG_SIZE, IMG_SIZE, 3), name='entrada_imagem')
cnn_branch = Rescaling(1./255)(input_cnn)
cnn_branch = Conv2D(32, 3, activation='relu')(cnn_branch)
cnn_branch = MaxPooling2D()(cnn_branch)
cnn_branch = Conv2D(64, 3, activation='relu')(cnn_branch)
cnn_branch = MaxPooling2D()(cnn_branch)
cnn_branch = Flatten()(cnn_branch)
cnn_branch = Dense(64, activation='relu')(cnn_branch)

input_lstm = Input(shape=(SEQ_LENGTH, len(features_lstm)), name='entrada_numerica')
lstm_branch = LSTM(units=50)(input_lstm)
lstm_branch = Dropout(0.2)(lstm_branch)
lstm_branch = Dense(25, activation='relu')(lstm_branch)

fused = concatenate([cnn_branch, lstm_branch])
final_head = Dense(64, activation='relu')(fused)
final_head = Dropout(0.5)(final_head)
final_output = Dense(len(class_names), activation='softmax', name='saida_final')(final_head)

hybrid_model = Model(inputs=[input_cnn, input_lstm], outputs=final_output, name="Cerebro_Hibrido")
hybrid_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hybrid_model.summary()


# ====================================================================
# Parte 6: GERADOR DE DADOS E TREINAMENTO
# ====================================================================

# O gerador é definido aqui, de forma limpa e correta
def data_generator(image_paths, lstm_sequences, labels, batch_size):
    num_samples = len(image_paths)
    while True:
        indices = np.arange(num_samples)
        np.random.shuffle(indices)
        for offset in range(0, num_samples, batch_size):
            batch_indices = indices[offset:offset+batch_size]

            batch_images = np.array([img_to_array(load_img(p, target_size=(IMG_SIZE, IMG_SIZE))) for p in image_paths[batch_indices]])
            batch_lstm = lstm_sequences[batch_indices]
            batch_labels = labels[batch_indices] # Directly use the numerical labels

            print(f"Type of batch_labels before yielding: {type(batch_labels)}")
            print(f"Dtype of batch_labels before yielding: {batch_labels.dtype}")
            print(f"Shape of batch_labels before yielding: {batch_labels.shape}")


            yield ({'entrada_imagem': batch_images, 'entrada_numerica': batch_lstm},
                   batch_labels) # Yield the numerical labels as a single array


# Criando os geradores para treino e validação
train_gen = data_generator(img_train_paths, X_train_lstm, y_train, BATCH_SIZE)
val_gen = data_generator(img_val_paths, X_val_lstm, y_val, BATCH_SIZE)

print("\nIniciando o treinamento do Cérebro Híbrido...")
early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True, verbose=1)

history_hybrid = hybrid_model.fit(
    train_gen,
    steps_per_epoch=len(y_train) // BATCH_SIZE,
    validation_data=val_gen,
    validation_steps=len(y_val) // BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[early_stopping]
)


# ====================================================================
# Parte 7: AVALIAÇÃO E PREVISÃO FINAL
# ====================================================================
print("\nFazendo previsão final com o Cérebro Híbrido...")
# Preparar os dados mais recentes para a previsão
dados_recentes_nao_normalizados = yf.download(TICKER, period=f"{SEQ_LENGTH+20}d", auto_adjust=True, progress=False) # +20 para garantir dados para indicadores
dados_recentes_nao_normalizados.dropna(inplace=True)

# Recalculate indicators for recent data using Pandas Series
window = 20
dados_recentes_nao_normalizados['volatility_bbm'] = dados_recentes_nao_normalizados['Close'].rolling(window=window).mean()
dados_recentes_nao_normalizados['volatility_bbh'] = dados_recentes_nao_normalizados['Close'].rolling(window=window).mean() + dados_recentes_nao_normalizados['Close'].rolling(window=window).std() * 2
dados_recentes_nao_normalizados['volatility_bbl'] = dados_recentes_nao_normalizados['Close'].rolling(window=window).mean() - dados_recentes_nao_normalizados['Close'].rolling(window=window).std() * 2

window_rsi = 14
delta_recente = dados_recentes_nao_normalizados['Close'].diff()
gain_recente = delta_recente.where(delta_recente > 0, 0)
loss_recente = -delta_recente.where(delta_recente < 0, 0)

avg_gain_recente = gain_recente.ewm(com=13, adjust=False).mean()
avg_loss_recente = loss_recente.ewm(com=13, adjust=False).mean()

rs_recente = avg_gain_recente / avg_loss_recente
rs_recente = rs_recente.replace([np.inf, -np.inf], np.nan).fillna(0)

dados_recentes_nao_normalizados['momentum_rsi'] = 100 - (100 / (1 + rs_recente))


dados_recentes_nao_normalizados.dropna(inplace=True)


dados_recentes_normalizados = dados_recentes_nao_normalizados.copy()
dados_recentes_normalizados[features_lstm] = scaler.transform(dados_recentes_nao_normalizados[features_lstm])
dados_para_previsao = dados_recentes_normalizados.tail(SEQ_LENGTH)

# Input Numérico
X_pred_lstm = dados_para_previsao[features_lstm].values
X_pred_lstm_expanded = np.expand_dims(X_pred_lstm, 0)

# Input Visual
nome_arquivo_pred = "pred_final.png"
caminho_pred = os.path.join(BASE_DIR, nome_arquivo_pred)
fig, ax = plt.subplots(3, 1, figsize=(IMG_SIZE/100, IMG_SIZE/100), dpi=100, gridspec_kw={'height_ratios': [2, 1, 1]})
ax[0].plot(dados_para_previsao['Close'].values, color='black')
ax[0].plot(dados_para_previsao['volatility_bbh'].values, color='blue', alpha=0.5)
ax[0].plot(dados_para_previsao['volatility_bbl'].values, color='blue', alpha=0.5)
ax[1].plot(dados_para_previsao['momentum_rsi'].values, color='purple')
ax[2].bar(range(len(dados_para_previsao)), dados_para_previsao['Volume'].values.flatten(), color='gray')
for axis in ax: axis.axis('off')
plt.subplots_adjust(left=0, right=1, top=1, bottom=0, hspace=0.01)
fig.savefig(caminho_pred, bbox_inches='tight', pad_inches=0)
plt.close(fig)

img_pred = load_img(caminho_pred, target_size=(IMG_SIZE, IMG_SIZE))
img_pred_array = np.expand_dims(img_to_array(img_pred), 0)

# Fazer a previsão com os dois inputs
prediction = hybrid_model.predict({'entrada_imagem': img_pred_array, 'entrada_numerica': X_pred_lstm_expanded})
score = prediction[0]

print("\n" + "="*60)
print(f"🔮 PREDIÇÃO HÍBRIDA PARA OS PRÓXIMOS {FUTURE_DAYS} DIAS DE {TICKER}")
print("="*60)
for i, class_name in enumerate(class_names):
    print(f"Probabilidade de {class_name}: {100 * score[i]:.2f}%")

predicted_class_index = np.argmax(score)
predicted_class = class_names[predicted_class_index]
print(f"\n🟢 TENDÊNCIA MAIS PROVÁVEL: {predicted_class}")
print("="*60)
# Out:
# Instalando e importando bibliotecas...
# Bibliotecas carregadas com sucesso!
#
# Definindo configurações globais...
# Configurações definidas e pastas criadas.
#
# Baixando dados históricos para VALE3.SA...
# Calculating technical indicators manually using Pandas Series...
# 2606 days of data processed with indicators.
#
# Gerando imagens e alinhando dados para o modelo híbrido...
# Total de 2541 exemplos gerados e alinhados.
# Dados divididos em 2032 para treino e 509 para validação.
#
# Construindo o Cérebro Híbrido (CNN + LSTM)...
# Model: "Cerebro_Hibrido"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ entrada_imagem      │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_3         │ (None, 128, 128,  │          0 │ entrada_imagem[0… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 126, 126,  │        896 │ rescaling_3[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 63, 63,    │          0 │ conv2d_6[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 61, 61,    │     18,496 │ max_pooling2d_6[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ entrada_numerica    │ (None, 60, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 30, 30,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 50)        │     11,400 │ entrada_numerica… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 57600)     │          0 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 50)        │          0 │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │  3,686,464 │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 25)        │      1,275 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 89)        │          0 │ dense_9[0][0],    │
# │ (Concatenate)       │                   │            │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 64)        │      5,760 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64)        │          0 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ saida_final (Dense) │ (None, 3)         │        195 │ dropout_7[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,724,486 (14.21 MB)
#  Trainable params: 3,724,486 (14.21 MB)
#  Non-trainable params: 0 (0.00 B)
# Iniciando o treinamento do Cérebro Híbrido...
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Epoch 1/40
#  1/63 ━━━━━━━━━━━━━━━━━━━━ 2:49 3s/step - accuracy: 0.3125 - loss: 1.1033Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  2/63 ━━━━━━━━━━━━━━━━━━━━ 26s 428ms/step - accuracy: 0.3359 - loss: 1.3472Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  3/63 ━━━━━━━━━━━━━━━━━━━━ 25s 417ms/step - accuracy: 0.3420 - loss: 1.5502Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  4/63 ━━━━━━━━━━━━━━━━━━━━ 24s 414ms/step - accuracy: 0.3366 - loss: 1.6305Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  5/63 ━━━━━━━━━━━━━━━━━━━━ 23s 410ms/step - accuracy: 0.3255 - loss: 1.6617Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  6/63 ━━━━━━━━━━━━━━━━━━━━ 23s 407ms/step - accuracy: 0.3181 - loss: 1.6693Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  7/63 ━━━━━━━━━━━━━━━━━━━━ 22s 405ms/step - accuracy: 0.3141 - loss: 1.6637Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  8/63 ━━━━━━━━━━━━━━━━━━━━ 22s 404ms/step - accuracy: 0.3120 - loss: 1.6510Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  9/63 ━━━━━━━━━━━━━━━━━━━━ 21s 406ms/step - accuracy: 0.3101 - loss: 1.6355Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 10/63 ━━━━━━━━━━━━━━━━━━━━ 22s 416ms/step - accuracy: 0.3091 - loss: 1.6192Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 11/63 ━━━━━━━━━━━━━━━━━━━━ 22s 436ms/step - accuracy: 0.3081 - loss: 1.6029Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 12/63 ━━━━━━━━━━━━━━━━━━━━ 22s 450ms/step - accuracy: 0.3074 - loss: 1.5871Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 13/63 ━━━━━━━━━━━━━━━━━━━━ 22s 452ms/step - accuracy: 0.3074 - loss: 1.5719Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 14/63 ━━━━━━━━━━━━━━━━━━━━ 21s 447ms/step - accuracy: 0.3076 - loss: 1.5572Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 15/63 ━━━━━━━━━━━━━━━━━━━━ 21s 443ms/step - accuracy: 0.3081 - loss: 1.5434Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 16/63 ━━━━━━━━━━━━━━━━━━━━ 20s 440ms/step - accuracy: 0.3091 - loss: 1.5301Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 17/63 ━━━━━━━━━━━━━━━━━━━━ 20s 437ms/step - accuracy: 0.3105 - loss: 1.5175Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 18/63 ━━━━━━━━━━━━━━━━━━━━ 19s 435ms/step - accuracy: 0.3123 - loss: 1.5055Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 19/63 ━━━━━━━━━━━━━━━━━━━━ 19s 433ms/step - accuracy: 0.3142 - loss: 1.4941Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 20/63 ━━━━━━━━━━━━━━━━━━━━ 18s 431ms/step - accuracy: 0.3159 - loss: 1.4835Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 21/63 ━━━━━━━━━━━━━━━━━━━━ 18s 430ms/step - accuracy: 0.3176 - loss: 1.4735Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 22/63 ━━━━━━━━━━━━━━━━━━━━ 17s 428ms/step - accuracy: 0.3195 - loss: 1.4639Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 23/63 ━━━━━━━━━━━━━━━━━━━━ 17s 427ms/step - accuracy: 0.3214 - loss: 1.4548Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 24/63 ━━━━━━━━━━━━━━━━━━━━ 16s 426ms/step - accuracy: 0.3234 - loss: 1.4460Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 25/63 ━━━━━━━━━━━━━━━━━━━━ 16s 425ms/step - accuracy: 0.3254 - loss: 1.4377Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 26/63 ━━━━━━━━━━━━━━━━━━━━ 15s 423ms/step - accuracy: 0.3273 - loss: 1.4297Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 27/63 ━━━━━━━━━━━━━━━━━━━━ 15s 423ms/step - accuracy: 0.3291 - loss: 1.4222Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 28/63 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.3310 - loss: 1.4149Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 29/63 ━━━━━━━━━━━━━━━━━━━━ 14s 420ms/step - accuracy: 0.3327 - loss: 1.4081Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 30/63 ━━━━━━━━━━━━━━━━━━━━ 13s 420ms/step - accuracy: 0.3344 - loss: 1.4015Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 31/63 ━━━━━━━━━━━━━━━━━━━━ 13s 419ms/step - accuracy: 0.3363 - loss: 1.3952Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 32/63 ━━━━━━━━━━━━━━━━━━━━ 12s 418ms/step - accuracy: 0.3383 - loss: 1.3890Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 33/63 ━━━━━━━━━━━━━━━━━━━━ 12s 418ms/step - accuracy: 0.3403 - loss: 1.3831Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 34/63 ━━━━━━━━━━━━━━━━━━━━ 12s 418ms/step - accuracy: 0.3421 - loss: 1.3774Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 35/63 ━━━━━━━━━━━━━━━━━━━━ 11s 417ms/step - accuracy: 0.3439 - loss: 1.3719Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 36/63 ━━━━━━━━━━━━━━━━━━━━ 11s 416ms/step - accuracy: 0.3458 - loss: 1.3666Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 37/63 ━━━━━━━━━━━━━━━━━━━━ 10s 416ms/step - accuracy: 0.3476 - loss: 1.3614Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 38/63 ━━━━━━━━━━━━━━━━━━━━ 10s 417ms/step - accuracy: 0.3494 - loss: 1.3564Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 39/63 ━━━━━━━━━━━━━━━━━━━━ 10s 422ms/step - accuracy: 0.3512 - loss: 1.3515Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 40/63 ━━━━━━━━━━━━━━━━━━━━ 9s 426ms/step - accuracy: 0.3530 - loss: 1.3469 Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 41/63 ━━━━━━━━━━━━━━━━━━━━ 9s 427ms/step - accuracy: 0.3547 - loss: 1.3424Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 42/63 ━━━━━━━━━━━━━━━━━━━━ 8s 426ms/step - accuracy: 0.3564 - loss: 1.3381Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 43/63 ━━━━━━━━━━━━━━━━━━━━ 8s 425ms/step - accuracy: 0.3580 - loss: 1.3340Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 44/63 ━━━━━━━━━━━━━━━━━━━━ 8s 424ms/step - accuracy: 0.3595 - loss: 1.3300Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 45/63 ━━━━━━━━━━━━━━━━━━━━ 7s 423ms/step - accuracy: 0.3610 - loss: 1.3261Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 46/63 ━━━━━━━━━━━━━━━━━━━━ 7s 422ms/step - accuracy: 0.3625 - loss: 1.3223Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 47/63 ━━━━━━━━━━━━━━━━━━━━ 6s 422ms/step - accuracy: 0.3639 - loss: 1.3187Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 48/63 ━━━━━━━━━━━━━━━━━━━━ 6s 421ms/step - accuracy: 0.3653 - loss: 1.3152Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 49/63 ━━━━━━━━━━━━━━━━━━━━ 5s 421ms/step - accuracy: 0.3667 - loss: 1.3118Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 50/63 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - accuracy: 0.3681 - loss: 1.3085Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 51/63 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - accuracy: 0.3694 - loss: 1.3052Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 52/63 ━━━━━━━━━━━━━━━━━━━━ 4s 419ms/step - accuracy: 0.3708 - loss: 1.3021Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 53/63 ━━━━━━━━━━━━━━━━━━━━ 4s 419ms/step - accuracy: 0.3722 - loss: 1.2990Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 54/63 ━━━━━━━━━━━━━━━━━━━━ 3s 419ms/step - accuracy: 0.3736 - loss: 1.2961Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 55/63 ━━━━━━━━━━━━━━━━━━━━ 3s 418ms/step - accuracy: 0.3748 - loss: 1.2932Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 56/63 ━━━━━━━━━━━━━━━━━━━━ 2s 418ms/step - accuracy: 0.3761 - loss: 1.2904Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 57/63 ━━━━━━━━━━━━━━━━━━━━ 2s 417ms/step - accuracy: 0.3773 - loss: 1.2877Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 58/63 ━━━━━━━━━━━━━━━━━━━━ 2s 417ms/step - accuracy: 0.3785 - loss: 1.2850Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 59/63 ━━━━━━━━━━━━━━━━━━━━ 1s 417ms/step - accuracy: 0.3796 - loss: 1.2824Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 60/63 ━━━━━━━━━━━━━━━━━━━━ 1s 416ms/step - accuracy: 0.3808 - loss: 1.2799Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 61/63 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.3819 - loss: 1.2774Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.3830 - loss: 1.2750Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (16,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.3840 - loss: 1.2726Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (29,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 459ms/step - accuracy: 0.3851 - loss: 1.2703 - val_accuracy: 0.4958 - val_loss: 1.0280
# Epoch 2/40
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  1/63 ━━━━━━━━━━━━━━━━━━━━ 12s 208ms/step - accuracy: 0.6875 - loss: 0.9482Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  2/63 ━━━━━━━━━━━━━━━━━━━━ 24s 407ms/step - accuracy: 0.6250 - loss: 0.9849Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  3/63 ━━━━━━━━━━━━━━━━━━━━ 24s 402ms/step - accuracy: 0.6042 - loss: 0.9978Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  4/63 ━━━━━━━━━━━━━━━━━━━━ 23s 399ms/step - accuracy: 0.5915 - loss: 1.0037Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  5/63 ━━━━━━━━━━━━━━━━━━━━ 23s 403ms/step - accuracy: 0.5829 - loss: 1.0075Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  6/63 ━━━━━━━━━━━━━━━━━━━━ 22s 402ms/step - accuracy: 0.5767 - loss: 1.0084Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  7/63 ━━━━━━━━━━━━━━━━━━━━ 22s 403ms/step - accuracy: 0.5692 - loss: 1.0101Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  8/63 ━━━━━━━━━━━━━━━━━━━━ 22s 402ms/step - accuracy: 0.5652 - loss: 1.0093Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  9/63 ━━━━━━━━━━━━━━━━━━━━ 21s 403ms/step - accuracy: 0.5600 - loss: 1.0105Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 10/63 ━━━━━━━━━━━━━━━━━━━━ 21s 401ms/step - accuracy: 0.5557 - loss: 1.0114Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 11/63 ━━━━━━━━━━━━━━━━━━━━ 20s 403ms/step - accuracy: 0.5514 - loss: 1.0121Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 12/63 ━━━━━━━━━━━━━━━━━━━━ 20s 404ms/step - accuracy: 0.5473 - loss: 1.0133Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 13/63 ━━━━━━━━━━━━━━━━━━━━ 20s 405ms/step - accuracy: 0.5441 - loss: 1.0142Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 14/63 ━━━━━━━━━━━━━━━━━━━━ 19s 404ms/step - accuracy: 0.5414 - loss: 1.0149Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 15/63 ━━━━━━━━━━━━━━━━━━━━ 19s 404ms/step - accuracy: 0.5385 - loss: 1.0161Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 16/63 ━━━━━━━━━━━━━━━━━━━━ 19s 404ms/step - accuracy: 0.5360 - loss: 1.0172Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 17/63 ━━━━━━━━━━━━━━━━━━━━ 18s 403ms/step - accuracy: 0.5334 - loss: 1.0185Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 18/63 ━━━━━━━━━━━━━━━━━━━━ 18s 403ms/step - accuracy: 0.5314 - loss: 1.0196Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 19/63 ━━━━━━━━━━━━━━━━━━━━ 17s 402ms/step - accuracy: 0.5295 - loss: 1.0206Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 20/63 ━━━━━━━━━━━━━━━━━━━━ 17s 403ms/step - accuracy: 0.5279 - loss: 1.0214Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 21/63 ━━━━━━━━━━━━━━━━━━━━ 16s 404ms/step - accuracy: 0.5263 - loss: 1.0222Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 22/63 ━━━━━━━━━━━━━━━━━━━━ 16s 403ms/step - accuracy: 0.5250 - loss: 1.0228Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 23/63 ━━━━━━━━━━━━━━━━━━━━ 16s 403ms/step - accuracy: 0.5236 - loss: 1.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 24/63 ━━━━━━━━━━━━━━━━━━━━ 15s 403ms/step - accuracy: 0.5223 - loss: 1.0243Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 25/63 ━━━━━━━━━━━━━━━━━━━━ 15s 403ms/step - accuracy: 0.5208 - loss: 1.0251Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 26/63 ━━━━━━━━━━━━━━━━━━━━ 15s 407ms/step - accuracy: 0.5195 - loss: 1.0259Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 27/63 ━━━━━━━━━━━━━━━━━━━━ 14s 415ms/step - accuracy: 0.5182 - loss: 1.0267Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 28/63 ━━━━━━━━━━━━━━━━━━━━ 14s 422ms/step - accuracy: 0.5169 - loss: 1.0274Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 29/63 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.5157 - loss: 1.0282Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 30/63 ━━━━━━━━━━━━━━━━━━━━ 13s 421ms/step - accuracy: 0.5146 - loss: 1.0289Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 31/63 ━━━━━━━━━━━━━━━━━━━━ 13s 421ms/step - accuracy: 0.5136 - loss: 1.0295Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 32/63 ━━━━━━━━━━━━━━━━━━━━ 13s 420ms/step - accuracy: 0.5126 - loss: 1.0302Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 33/63 ━━━━━━━━━━━━━━━━━━━━ 12s 418ms/step - accuracy: 0.5117 - loss: 1.0309Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 34/63 ━━━━━━━━━━━━━━━━━━━━ 12s 418ms/step - accuracy: 0.5108 - loss: 1.0314Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 35/63 ━━━━━━━━━━━━━━━━━━━━ 11s 417ms/step - accuracy: 0.5100 - loss: 1.0320Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 36/63 ━━━━━━━━━━━━━━━━━━━━ 11s 417ms/step - accuracy: 0.5093 - loss: 1.0325Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 37/63 ━━━━━━━━━━━━━━━━━━━━ 10s 416ms/step - accuracy: 0.5086 - loss: 1.0329Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 38/63 ━━━━━━━━━━━━━━━━━━━━ 10s 416ms/step - accuracy: 0.5081 - loss: 1.0332Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 39/63 ━━━━━━━━━━━━━━━━━━━━ 9s 415ms/step - accuracy: 0.5075 - loss: 1.0336 Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 40/63 ━━━━━━━━━━━━━━━━━━━━ 9s 415ms/step - accuracy: 0.5068 - loss: 1.0340Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 41/63 ━━━━━━━━━━━━━━━━━━━━ 9s 414ms/step - accuracy: 0.5063 - loss: 1.0343Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 42/63 ━━━━━━━━━━━━━━━━━━━━ 8s 414ms/step - accuracy: 0.5058 - loss: 1.0346Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 43/63 ━━━━━━━━━━━━━━━━━━━━ 8s 413ms/step - accuracy: 0.5053 - loss: 1.0348Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 44/63 ━━━━━━━━━━━━━━━━━━━━ 7s 413ms/step - accuracy: 0.5048 - loss: 1.0350Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 45/63 ━━━━━━━━━━━━━━━━━━━━ 7s 412ms/step - accuracy: 0.5043 - loss: 1.0353Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 46/63 ━━━━━━━━━━━━━━━━━━━━ 6s 412ms/step - accuracy: 0.5038 - loss: 1.0355Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 47/63 ━━━━━━━━━━━━━━━━━━━━ 6s 411ms/step - accuracy: 0.5033 - loss: 1.0357Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 48/63 ━━━━━━━━━━━━━━━━━━━━ 6s 411ms/step - accuracy: 0.5028 - loss: 1.0359Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 49/63 ━━━━━━━━━━━━━━━━━━━━ 5s 411ms/step - accuracy: 0.5025 - loss: 1.0361Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 50/63 ━━━━━━━━━━━━━━━━━━━━ 5s 411ms/step - accuracy: 0.5022 - loss: 1.0362Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 51/63 ━━━━━━━━━━━━━━━━━━━━ 4s 411ms/step - accuracy: 0.5018 - loss: 1.0364Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 52/63 ━━━━━━━━━━━━━━━━━━━━ 4s 411ms/step - accuracy: 0.5016 - loss: 1.0365Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 53/63 ━━━━━━━━━━━━━━━━━━━━ 4s 410ms/step - accuracy: 0.5013 - loss: 1.0366Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 54/63 ━━━━━━━━━━━━━━━━━━━━ 3s 414ms/step - accuracy: 0.5012 - loss: 1.0367Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 55/63 ━━━━━━━━━━━━━━━━━━━━ 3s 417ms/step - accuracy: 0.5010 - loss: 1.0367Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 56/63 ━━━━━━━━━━━━━━━━━━━━ 2s 419ms/step - accuracy: 0.5008 - loss: 1.0368Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 57/63 ━━━━━━━━━━━━━━━━━━━━ 2s 419ms/step - accuracy: 0.5007 - loss: 1.0368Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 58/63 ━━━━━━━━━━━━━━━━━━━━ 2s 418ms/step - accuracy: 0.5006 - loss: 1.0368Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 59/63 ━━━━━━━━━━━━━━━━━━━━ 1s 418ms/step - accuracy: 0.5004 - loss: 1.0368Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 60/63 ━━━━━━━━━━━━━━━━━━━━ 1s 418ms/step - accuracy: 0.5003 - loss: 1.0369Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 61/63 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.5001 - loss: 1.0369Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.5000 - loss: 1.0370Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.4998 - loss: 1.0370Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 40s 648ms/step - accuracy: 0.4997 - loss: 1.0370 - val_accuracy: 0.5229 - val_loss: 0.9948
# Epoch 3/40
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (16,)
#  1/63 ━━━━━━━━━━━━━━━━━━━━ 24s 396ms/step - accuracy: 0.5312 - loss: 0.9814Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  2/63 ━━━━━━━━━━━━━━━━━━━━ 14s 236ms/step - accuracy: 0.5469 - loss: 0.9784Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  3/63 ━━━━━━━━━━━━━━━━━━━━ 19s 322ms/step - accuracy: 0.5479 - loss: 0.9945Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  4/63 ━━━━━━━━━━━━━━━━━━━━ 20s 347ms/step - accuracy: 0.5538 - loss: 0.9966Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  5/63 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.5583 - loss: 0.9948Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  6/63 ━━━━━━━━━━━━━━━━━━━━ 20s 368ms/step - accuracy: 0.5571 - loss: 0.9965Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  7/63 ━━━━━━━━━━━━━━━━━━━━ 21s 375ms/step - accuracy: 0.5572 - loss: 0.9957Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  8/63 ━━━━━━━━━━━━━━━━━━━━ 20s 378ms/step - accuracy: 0.5558 - loss: 0.9952Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  9/63 ━━━━━━━━━━━━━━━━━━━━ 20s 379ms/step - accuracy: 0.5545 - loss: 0.9959Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 10/63 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - accuracy: 0.5527 - loss: 0.9963Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 11/63 ━━━━━━━━━━━━━━━━━━━━ 21s 412ms/step - accuracy: 0.5508 - loss: 0.9960Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 12/63 ━━━━━━━━━━━━━━━━━━━━ 21s 430ms/step - accuracy: 0.5489 - loss: 0.9957Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 13/63 ━━━━━━━━━━━━━━━━━━━━ 21s 434ms/step - accuracy: 0.5465 - loss: 0.9958Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 14/63 ━━━━━━━━━━━━━━━━━━━━ 21s 433ms/step - accuracy: 0.5443 - loss: 0.9960Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 15/63 ━━━━━━━━━━━━━━━━━━━━ 20s 431ms/step - accuracy: 0.5425 - loss: 0.9964Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 16/63 ━━━━━━━━━━━━━━━━━━━━ 20s 430ms/step - accuracy: 0.5415 - loss: 0.9962Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 17/63 ━━━━━━━━━━━━━━━━━━━━ 19s 429ms/step - accuracy: 0.5410 - loss: 0.9958Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 18/63 ━━━━━━━━━━━━━━━━━━━━ 19s 429ms/step - accuracy: 0.5407 - loss: 0.9953Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 19/63 ━━━━━━━━━━━━━━━━━━━━ 18s 428ms/step - accuracy: 0.5406 - loss: 0.9947Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 20/63 ━━━━━━━━━━━━━━━━━━━━ 18s 426ms/step - accuracy: 0.5401 - loss: 0.9947Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 21/63 ━━━━━━━━━━━━━━━━━━━━ 17s 426ms/step - accuracy: 0.5398 - loss: 0.9944Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 22/63 ━━━━━━━━━━━━━━━━━━━━ 17s 425ms/step - accuracy: 0.5397 - loss: 0.9941Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 23/63 ━━━━━━━━━━━━━━━━━━━━ 16s 423ms/step - accuracy: 0.5395 - loss: 0.9941Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 24/63 ━━━━━━━━━━━━━━━━━━━━ 16s 422ms/step - accuracy: 0.5389 - loss: 0.9941Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 25/63 ━━━━━━━━━━━━━━━━━━━━ 16s 422ms/step - accuracy: 0.5383 - loss: 0.9941Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 26/63 ━━━━━━━━━━━━━━━━━━━━ 15s 422ms/step - accuracy: 0.5377 - loss: 0.9941Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 27/63 ━━━━━━━━━━━━━━━━━━━━ 15s 421ms/step - accuracy: 0.5373 - loss: 0.9940Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 28/63 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.5367 - loss: 0.9940Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 29/63 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.5361 - loss: 0.9942Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 30/63 ━━━━━━━━━━━━━━━━━━━━ 13s 420ms/step - accuracy: 0.5355 - loss: 0.9942Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 31/63 ━━━━━━━━━━━━━━━━━━━━ 13s 419ms/step - accuracy: 0.5349 - loss: 0.9943Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 32/63 ━━━━━━━━━━━━━━━━━━━━ 12s 418ms/step - accuracy: 0.5344 - loss: 0.9942Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 33/63 ━━━━━━━━━━━━━━━━━━━━ 12s 417ms/step - accuracy: 0.5340 - loss: 0.9941Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 34/63 ━━━━━━━━━━━━━━━━━━━━ 12s 416ms/step - accuracy: 0.5336 - loss: 0.9941Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 35/63 ━━━━━━━━━━━━━━━━━━━━ 11s 415ms/step - accuracy: 0.5331 - loss: 0.9941Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 36/63 ━━━━━━━━━━━━━━━━━━━━ 11s 414ms/step - accuracy: 0.5326 - loss: 0.9941Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 37/63 ━━━━━━━━━━━━━━━━━━━━ 10s 414ms/step - accuracy: 0.5322 - loss: 0.9940Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 38/63 ━━━━━━━━━━━━━━━━━━━━ 10s 418ms/step - accuracy: 0.5318 - loss: 0.9940Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 39/63 ━━━━━━━━━━━━━━━━━━━━ 10s 425ms/step - accuracy: 0.5314 - loss: 0.9940Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 40/63 ━━━━━━━━━━━━━━━━━━━━ 9s 427ms/step - accuracy: 0.5309 - loss: 0.9941 Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 41/63 ━━━━━━━━━━━━━━━━━━━━ 9s 427ms/step - accuracy: 0.5305 - loss: 0.9942Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 42/63 ━━━━━━━━━━━━━━━━━━━━ 8s 427ms/step - accuracy: 0.5301 - loss: 0.9942Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 43/63 ━━━━━━━━━━━━━━━━━━━━ 8s 426ms/step - accuracy: 0.5297 - loss: 0.9943Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 44/63 ━━━━━━━━━━━━━━━━━━━━ 8s 425ms/step - accuracy: 0.5293 - loss: 0.9944Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 45/63 ━━━━━━━━━━━━━━━━━━━━ 7s 425ms/step - accuracy: 0.5288 - loss: 0.9945Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# ...
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  6/63 ━━━━━━━━━━━━━━━━━━━━ 29s 512ms/step - accuracy: 0.9866 - loss: 0.0587Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  7/63 ━━━━━━━━━━━━━━━━━━━━ 27s 497ms/step - accuracy: 0.9854 - loss: 0.0608Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  8/63 ━━━━━━━━━━━━━━━━━━━━ 26s 486ms/step - accuracy: 0.9847 - loss: 0.0620Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  9/63 ━━━━━━━━━━━━━━━━━━━━ 25s 477ms/step - accuracy: 0.9841 - loss: 0.0630Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (16,)
# 10/63 ━━━━━━━━━━━━━━━━━━━━ 24s 469ms/step - accuracy: 0.9838 - loss: 0.0632Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 11/63 ━━━━━━━━━━━━━━━━━━━━ 23s 445ms/step - accuracy: 0.9837 - loss: 0.0632Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 12/63 ━━━━━━━━━━━━━━━━━━━━ 22s 442ms/step - accuracy: 0.9837 - loss: 0.0628Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 13/63 ━━━━━━━━━━━━━━━━━━━━ 22s 441ms/step - accuracy: 0.9836 - loss: 0.0629Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 14/63 ━━━━━━━━━━━━━━━━━━━━ 21s 439ms/step - accuracy: 0.9833 - loss: 0.0637Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 15/63 ━━━━━━━━━━━━━━━━━━━━ 21s 438ms/step - accuracy: 0.9830 - loss: 0.0648Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 16/63 ━━━━━━━━━━━━━━━━━━━━ 20s 435ms/step - accuracy: 0.9826 - loss: 0.0665Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 17/63 ━━━━━━━━━━━━━━━━━━━━ 19s 434ms/step - accuracy: 0.9824 - loss: 0.0679Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 18/63 ━━━━━━━━━━━━━━━━━━━━ 19s 432ms/step - accuracy: 0.9823 - loss: 0.0689Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 19/63 ━━━━━━━━━━━━━━━━━━━━ 18s 431ms/step - accuracy: 0.9823 - loss: 0.0697Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 20/63 ━━━━━━━━━━━━━━━━━━━━ 18s 431ms/step - accuracy: 0.9823 - loss: 0.0703Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 21/63 ━━━━━━━━━━━━━━━━━━━━ 18s 429ms/step - accuracy: 0.9823 - loss: 0.0707Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 22/63 ━━━━━━━━━━━━━━━━━━━━ 17s 429ms/step - accuracy: 0.9823 - loss: 0.0712Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 23/63 ━━━━━━━━━━━━━━━━━━━━ 17s 429ms/step - accuracy: 0.9824 - loss: 0.0716Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 24/63 ━━━━━━━━━━━━━━━━━━━━ 16s 429ms/step - accuracy: 0.9824 - loss: 0.0720Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 25/63 ━━━━━━━━━━━━━━━━━━━━ 16s 429ms/step - accuracy: 0.9824 - loss: 0.0723Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 26/63 ━━━━━━━━━━━━━━━━━━━━ 15s 429ms/step - accuracy: 0.9824 - loss: 0.0725Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 27/63 ━━━━━━━━━━━━━━━━━━━━ 15s 429ms/step - accuracy: 0.9825 - loss: 0.0727Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 28/63 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.9825 - loss: 0.0728Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 29/63 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.9826 - loss: 0.0729Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 30/63 ━━━━━━━━━━━━━━━━━━━━ 14s 432ms/step - accuracy: 0.9827 - loss: 0.0729Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 31/63 ━━━━━━━━━━━━━━━━━━━━ 14s 438ms/step - accuracy: 0.9828 - loss: 0.0729Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 32/63 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.9829 - loss: 0.0729Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 33/63 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.9830 - loss: 0.0728Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 34/63 ━━━━━━━━━━━━━━━━━━━━ 12s 441ms/step - accuracy: 0.9831 - loss: 0.0727Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 35/63 ━━━━━━━━━━━━━━━━━━━━ 12s 440ms/step - accuracy: 0.9832 - loss: 0.0726Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 36/63 ━━━━━━━━━━━━━━━━━━━━ 11s 439ms/step - accuracy: 0.9834 - loss: 0.0725Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 37/63 ━━━━━━━━━━━━━━━━━━━━ 11s 439ms/step - accuracy: 0.9835 - loss: 0.0723Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 38/63 ━━━━━━━━━━━━━━━━━━━━ 10s 439ms/step - accuracy: 0.9836 - loss: 0.0722Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 39/63 ━━━━━━━━━━━━━━━━━━━━ 10s 438ms/step - accuracy: 0.9836 - loss: 0.0721Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 40/63 ━━━━━━━━━━━━━━━━━━━━ 10s 437ms/step - accuracy: 0.9837 - loss: 0.0719Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 41/63 ━━━━━━━━━━━━━━━━━━━━ 9s 437ms/step - accuracy: 0.9838 - loss: 0.0718 Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 42/63 ━━━━━━━━━━━━━━━━━━━━ 9s 435ms/step - accuracy: 0.9838 - loss: 0.0717Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 43/63 ━━━━━━━━━━━━━━━━━━━━ 8s 435ms/step - accuracy: 0.9838 - loss: 0.0717Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 44/63 ━━━━━━━━━━━━━━━━━━━━ 8s 434ms/step - accuracy: 0.9838 - loss: 0.0716Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 45/63 ━━━━━━━━━━━━━━━━━━━━ 7s 434ms/step - accuracy: 0.9838 - loss: 0.0715Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 46/63 ━━━━━━━━━━━━━━━━━━━━ 7s 433ms/step - accuracy: 0.9839 - loss: 0.0714Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 47/63 ━━━━━━━━━━━━━━━━━━━━ 6s 433ms/step - accuracy: 0.9839 - loss: 0.0713Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 48/63 ━━━━━━━━━━━━━━━━━━━━ 6s 433ms/step - accuracy: 0.9839 - loss: 0.0712Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 49/63 ━━━━━━━━━━━━━━━━━━━━ 6s 432ms/step - accuracy: 0.9839 - loss: 0.0712Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 50/63 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - accuracy: 0.9839 - loss: 0.0711Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 51/63 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - accuracy: 0.9839 - loss: 0.0710Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 52/63 ━━━━━━━━━━━━━━━━━━━━ 4s 431ms/step - accuracy: 0.9840 - loss: 0.0708Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 53/63 ━━━━━━━━━━━━━━━━━━━━ 4s 430ms/step - accuracy: 0.9840 - loss: 0.0707Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 54/63 ━━━━━━━━━━━━━━━━━━━━ 3s 430ms/step - accuracy: 0.9840 - loss: 0.0706Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 55/63 ━━━━━━━━━━━━━━━━━━━━ 3s 430ms/step - accuracy: 0.9840 - loss: 0.0705Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 56/63 ━━━━━━━━━━━━━━━━━━━━ 3s 430ms/step - accuracy: 0.9841 - loss: 0.0704Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 57/63 ━━━━━━━━━━━━━━━━━━━━ 2s 432ms/step - accuracy: 0.9841 - loss: 0.0703Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 58/63 ━━━━━━━━━━━━━━━━━━━━ 2s 436ms/step - accuracy: 0.9841 - loss: 0.0702Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 59/63 ━━━━━━━━━━━━━━━━━━━━ 1s 438ms/step - accuracy: 0.9841 - loss: 0.0700Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 60/63 ━━━━━━━━━━━━━━━━━━━━ 1s 437ms/step - accuracy: 0.9841 - loss: 0.0700Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 61/63 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9841 - loss: 0.0700Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9841 - loss: 0.0700Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9841 - loss: 0.0700Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (29,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 41s 653ms/step - accuracy: 0.9841 - loss: 0.0700 - val_accuracy: 0.6164 - val_loss: 2.0270
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 4.
#
# Fazendo previsão final com o Cérebro Híbrido...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
#
# ============================================================
# 🔮 PREDIÇÃO HÍBRIDA PARA OS PRÓXIMOS 5 DIAS DE VALE3.SA
# ============================================================
# Probabilidade de ALTA: 5.80%
# Probabilidade de BAIXA: 8.56%
# Probabilidade de NEUTRA: 85.64%
#
# 🟢 TENDÊNCIA MAIS PROVÁVEL: NEUTRA
# ============================================================
