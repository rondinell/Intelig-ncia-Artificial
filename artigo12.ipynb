# %% [markdown]
# <a href="https://colab.research.google.com/github/rondinell/Intelig-ncia-Artificial/blob/main/artigo12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ====================================================================
# CÉLULA 1: INSTALAÇÃO E IMPORTAÇÕES
# ====================================================================
print("Instalando bibliotecas necessárias...")
# !pip install yfinance ta --quiet

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ta
import os
import shutil
from datetime import date

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Rescaling
from tensorflow.keras.utils import image_dataset_from_directory, load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping # Importação do Early Stopping

print("Bibliotecas carregadas com sucesso!")

# ====================================================================
# CÉLULA 2: CONFIGURAÇÕES GLOBAIS
# ====================================================================
#---------------------------------------------------------------------
# --- Configurações do Ativo e Datas ---
#---------------------------------------------------------------------
TICKER = 'VALE3.SA'
START_DATE = '2015-01-01'
END_DATE = date.today().strftime("%Y-%m-%d")

# --- Configurações para Geração das Imagens e Rótulos ---
SEQ_LENGTH = 60
FUTURE_DAYS = 5
THRESHOLD = 0.02

# --- Configurações das Imagens e do Modelo ---
IMG_SIZE = 128
BATCH_SIZE = 32
EPOCHS = 30 # Aumentamos as épocas, pois o Early Stopping vai parar quando for o ideal

# --- Configurações de Pastas ---
BASE_DIR = '/content/stock_data'
if os.path.exists(BASE_DIR):
    shutil.rmtree(BASE_DIR)

os.makedirs(os.path.join(BASE_DIR, 'train', 'ALTA'), exist_ok=True)
os.makedirs(os.path.join(BASE_DIR, 'train', 'BAIXA'), exist_ok=True)
os.makedirs(os.path.join(BASE_DIR, 'train', 'NEUTRA'), exist_ok=True)

print("Configurações definidas e pastas criadas.")

# ====================================================================
# CÉLULA 3: DOWNLOAD E PREPARAÇÃO DOS DADOS
# ====================================================================
print(f"Baixando dados históricos para {TICKER}...")
data = yf.download(TICKER, start=START_DATE, end=END_DATE, progress=False)
data.dropna(inplace=True)
data.columns = data.columns.get_level_values(0)

# Adiciona todos os indicadores técnicos da biblioteca 'ta'
print("Calculando indicadores técnicos...")
data = ta.add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)
print(f"{len(data)} dias de dados baixados e processados.")


# ====================================================================
# CÉLULA 4: GERADOR DE IMAGENS COM MÚLTIPLOS GRÁFICOS
# ====================================================================
print("Iniciando geração de imagens e rótulos (com múltiplos gráficos)...")
count = {'ALTA': 0, 'BAIXA': 0, 'NEUTRA': 0}

for i in range(len(data) - SEQ_LENGTH - FUTURE_DAYS):
    dados_janela = data.iloc[i : i + SEQ_LENGTH]
    preco_final_janela = dados_janela.iloc[-1]['Close']
    preco_futuro = data.iloc[i + SEQ_LENGTH + FUTURE_DAYS - 1]['Close']

    label = 'NEUTRA'
    if preco_futuro > preco_final_janela * (1 + THRESHOLD):
        label = 'ALTA'
    elif preco_futuro < preco_final_janela * (1 - THRESHOLD):
        label = 'BAIXA'
    count[label] += 1

    pasta_destino = os.path.join(BASE_DIR, 'train', label)
    nome_arquivo = f"{data.index[i].strftime('%Y-%m-%d')}.png"
    caminho_completo = os.path.join(pasta_destino, nome_arquivo)

    # Criação de 2 subplots empilhados verticalmente
    fig, ax = plt.subplots(
        2, 1,
        figsize=(IMG_SIZE/100, IMG_SIZE/100),
        dpi=100,
        gridspec_kw={'height_ratios': [3, 1]}
    )
    fig.tight_layout()

    # --- PLOT 1: Preço e Bandas de Bollinger ---
    ax[0].plot(dados_janela['Close'].values, color='black', linewidth=1.0)
    ax[0].plot(dados_janela['volatility_bbh'].values, color='blue', linewidth=0.5, alpha=0.5)
    ax[0].plot(dados_janela['volatility_bbl'].values, color='blue', linewidth=0.5, alpha=0.5)
    ax[0].plot(dados_janela['volatility_bbm'].values, color='red', linewidth=0.5, alpha=0.7, linestyle='--')

    # --- PLOT 2: RSI (Índice de Força Relativa) ---
    ax[1].plot(dados_janela['momentum_rsi'].values, color='purple', linewidth=0.8)
    ax[1].axhline(70, color='gray', linestyle='--', linewidth=0.5, alpha=0.8)
    ax[1].axhline(30, color='gray', linestyle='--', linewidth=0.5, alpha=0.8)

    # Remove os eixos de ambos os gráficos
    ax[0].axis('off')
    ax[1].axis('off')

    fig.savefig(caminho_completo, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

print("Geração de imagens aprimoradas concluída!")
print(f"Total de imagens geradas: {sum(count.values())}")
print(f"Distribuição: {count}")

# ====================================================================
# CÉLULA 5: PREPARAÇÃO DOS DADOS PARA O MODELO
# ====================================================================
print("Carregando e preparando os datasets de imagens...")

train_dataset_raw = image_dataset_from_directory(
    os.path.join(BASE_DIR, 'train'),
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)
class_names = train_dataset_raw.class_names

validation_dataset_raw = image_dataset_from_directory(
    os.path.join(BASE_DIR, 'train'),
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset_raw.cache().prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset_raw.cache().prefetch(buffer_size=AUTOTUNE)

print(f"Classes encontradas: {class_names}")

# ====================================================================
# CÉLULA 6: CONSTRUÇÃO DO MODELO CNN
# ====================================================================
print("Construindo o modelo CNN...")

model_cnn = Sequential([
    Input(shape=(IMG_SIZE, IMG_SIZE, 3)),
    Rescaling(1./255),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(128, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.5), # Dropout aumentado para 0.5
    Flatten(),
    Dense(128, activation='relu'),
    Dense(len(class_names), activation='softmax')
])

model_cnn.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model_cnn.summary()

# ====================================================================
# CÉLULA 7: TREINAMENTO DO MODELO
# ====================================================================
print("Iniciando o treinamento da CNN...")

# Definição do callback de Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True) # Aumentei a paciência para 5

history = model_cnn.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=EPOCHS,
    callbacks=[early_stopping] # Adição do callback
)
print("Treinamento concluído!")

# ====================================================================
# CÉLULA 8: AVALIAÇÃO E PREVISÃO
# ====================================================================
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Acurácia de Treino')
plt.plot(epochs_range, val_acc, label='Acurácia de Validação')
plt.legend(loc='lower right')
plt.title('Acurácia de Treino e Validação')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Perda de Treino')
plt.plot(epochs_range, val_loss, label='Perda de Validação')
plt.legend(loc='upper right')
plt.title('Perda de Treino e Validação')
plt.show()

print("\nFazendo previsão com os dados mais recentes...")
dados_recentes = data.iloc[-SEQ_LENGTH:]

fig, ax = plt.subplots(2, 1, figsize=(IMG_SIZE/100, IMG_SIZE/100), dpi=100, gridspec_kw={'height_ratios': [3, 1]})
fig.tight_layout()
ax[0].plot(dados_recentes['Close'].values, color='black', linewidth=1.0)
ax[0].plot(dados_recentes['volatility_bbh'].values, color='blue', linewidth=0.5, alpha=0.5)
ax[0].plot(dados_recentes['volatility_bbl'].values, color='blue', linewidth=0.5, alpha=0.5)
ax[0].plot(dados_recentes['volatility_bbm'].values, color='red', linewidth=0.5, alpha=0.7, linestyle='--')
ax[1].plot(dados_recentes['momentum_rsi'].values, color='purple', linewidth=0.8)
ax[1].axhline(70, color='gray', linestyle='--', linewidth=0.5, alpha=0.8)
ax[1].axhline(30, color='gray', linestyle='--', linewidth=0.5, alpha=0.8)
ax[0].axis('off')
ax[1].axis('off')
caminho_predicao = '/content/pred_temp.png'
fig.savefig(caminho_predicao, bbox_inches='tight', pad_inches=0)
plt.close(fig)

img = load_img(caminho_predicao, target_size=(IMG_SIZE, IMG_SIZE))
img_array = img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model_cnn.predict(img_array)
score = tf.nn.softmax(predictions[0])

print("\n" + "="*60)
print(f"🔮 PREDIÇÃO PARA OS PRÓXIMOS {FUTURE_DAYS} DIAS DE {TICKER}")
print("="*60)
for i in range(len(class_names)):
    print(f"Probabilidade de {class_names[i]}: {100 * score[i]:.2f}%")
predicted_class = class_names[np.argmax(score)]
print(f"\n🟢 TENDÊNCIA MAIS PROVÁVEL: {predicted_class}")
print("="*60)
# Out:
# Instalando bibliotecas necessárias...
#   Preparing metadata (setup.py) ... done
#   Building wheel for ta (setup.py) ... done
# Bibliotecas carregadas com sucesso!
# Configurações definidas e pastas criadas.
# Baixando dados históricos para VALE3.SA...
# /tmp/ipython-input-2-1315746707.py:59: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(TICKER, start=START_DATE, end=END_DATE, progress=False)
# Calculando indicadores técnicos...
# /usr/local/lib/python3.11/dist-packages/ta/trend.py:1030: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self._psar[i] = high2
# 2618 dias de dados baixados e processados.
# Iniciando geração de imagens e rótulos (com múltiplos gráficos)...
# Geração de imagens aprimoradas concluída!
# Total de imagens geradas: 2553
# Distribuição: {'ALTA': 912, 'BAIXA': 740, 'NEUTRA': 901}
# Carregando e preparando os datasets de imagens...
# Found 2553 files belonging to 3 classes.
# Using 2043 files for training.
# Found 2553 files belonging to 3 classes.
# Using 510 files for validation.
# Classes encontradas: ['ALTA', 'BAIXA', 'NEUTRA']
# Construindo o modelo CNN...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     4,194,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,288,067 (16.36 MB)
#  Trainable params: 4,288,067 (16.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Iniciando o treinamento da CNN...
# Epoch 1/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.3623 - loss: 1.2203 - val_accuracy: 0.3392 - val_loss: 1.0950
# Epoch 2/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.3518 - loss: 1.0970 - val_accuracy: 0.3745 - val_loss: 1.0940
# Epoch 3/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.3492 - loss: 1.0966 - val_accuracy: 0.3392 - val_loss: 1.0942
# Epoch 4/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.3465 - loss: 1.0962 - val_accuracy: 0.3725 - val_loss: 1.0938
# Epoch 5/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.3482 - loss: 1.0972 - val_accuracy: 0.3765 - val_loss: 1.0937
# Epoch 6/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.3495 - loss: 1.0964 - val_accuracy: 0.3686 - val_loss: 1.0915
# Epoch 7/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.3697 - loss: 1.0926 - val_accuracy: 0.3804 - val_loss: 1.0917
# Epoch 8/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.3681 - loss: 1.0891 - val_accuracy: 0.4039 - val_loss: 1.0775
# Epoch 9/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.4073 - loss: 1.0687 - val_accuracy: 0.4275 - val_loss: 1.0663
# Epoch 10/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.4516 - loss: 1.0502 - val_accuracy: 0.4608 - val_loss: 1.0439
# Epoch 11/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.4745 - loss: 1.0100 - val_accuracy: 0.4706 - val_loss: 1.0259
# Epoch 12/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.5153 - loss: 0.9929 - val_accuracy: 0.4706 - val_loss: 1.0225
# Epoch 13/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.5473 - loss: 0.9303 - val_accuracy: 0.5157 - val_loss: 1.0046
# Epoch 14/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.5776 - loss: 0.8778 - val_accuracy: 0.5294 - val_loss: 0.9935
# Epoch 15/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.6135 - loss: 0.8340 - val_accuracy: 0.5412 - val_loss: 0.9781
# Epoch 16/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.6458 - loss: 0.7986 - val_accuracy: 0.5608 - val_loss: 0.9755
# Epoch 17/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.6889 - loss: 0.7169 - val_accuracy: 0.5549 - val_loss: 1.0285
# Epoch 18/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7003 - loss: 0.6883 - val_accuracy: 0.5510 - val_loss: 1.0139
# Epoch 19/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7378 - loss: 0.6230 - val_accuracy: 0.5706 - val_loss: 1.0764
# Epoch 20/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.7655 - loss: 0.5786 - val_accuracy: 0.5725 - val_loss: 1.0650
# Epoch 21/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.7832 - loss: 0.5666 - val_accuracy: 0.6118 - val_loss: 0.9865
# Treinamento concluído!
# Fazendo previsão com os dados mais recentes...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
#
# ============================================================
# 🔮 PREDIÇÃO PARA OS PRÓXIMOS 5 DIAS DE VALE3.SA
# ============================================================
# Probabilidade de ALTA: 22.41%
# Probabilidade de BAIXA: 26.94%
# Probabilidade de NEUTRA: 50.65%
#
# 🟢 TENDÊNCIA MAIS PROVÁVEL: NEUTRA
# ============================================================
