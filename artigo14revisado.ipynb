# %% [markdown]
# <a href="https://colab.research.google.com/github/rondinell/Intelig-ncia-Artificial/blob/main/artigo14revisado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================================================================
# Parte 1: INSTALAÇÃO E IMPORTAÇÕES
# IA NOS INVESTIMENTOS: ESTUDO AVANÇADO
# Combinando uma LSTM (Estrategista) com um CNN (Analista de Risco usando gráficos)
# Autor: Rondinelli Alves de Andrade, com assistência de IA
# =======================================================================================
print("Instalando e importando bibliotecas...")
# !pip install yfinance mplfinance --quiet # Removendo biblioteca  ta para no futuro calcular de forma manual

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
from datetime import date
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Rescaling, LSTM, concatenate
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping

print("Bibliotecas carregadas com sucesso!")


# ====================================================================
# Parte 2: CONFIGURAÇÕES GLOBAIS
# ====================================================================
print("\nDefinindo configurações globais...")
TICKER = 'VALE3.SA'
START_DATE = '2015-01-01'
END_DATE = date.today().strftime("%Y-%m-%d")
SEQ_LENGTH = 60
FUTURE_DAYS = 5
THRESHOLD = 0.03
IMG_SIZE = 128
BATCH_SIZE = 32
EPOCHS = 40
BASE_DIR = '/content/stock_data_hybrid'

if os.path.exists(BASE_DIR):
    shutil.rmtree(BASE_DIR)
os.makedirs(BASE_DIR, exist_ok=True)
print("Configurações definidas e pastas criadas.")


# ====================================================================
# Parte 3: DOWNLOAD E CÁLCULO MANUAL DE INDICADORES (Using Pandas Series)
# ====================================================================
print(f"\nBaixando dados históricos para {TICKER}...")
data = yf.download(TICKER, start=START_DATE, end=END_DATE, auto_adjust=True, progress=False)
data.dropna(inplace=True)

print("Calculating technical indicators manually using Pandas Series...")

# Calculate Bollinger Bands directly on pandas Series
window = 20
data['volatility_bbm'] = data['Close'].rolling(window=window).mean()
data['volatility_bbh'] = data['Close'].rolling(window=window).mean() + data['Close'].rolling(window=window).std() * 2
data['volatility_bbl'] = data['Close'].rolling(window=window).mean() - data['Close'].rolling(window=window).std() * 2

# Calculate RSI directly on pandas Series using EMA
window_rsi = 14
delta = data['Close'].diff()
gain = delta.where(delta > 0, 0)
loss = -delta.where(delta < 0, 0)

avg_gain = gain.ewm(com=window_rsi - 1, adjust=False).mean()
avg_loss = loss.ewm(com=window_rsi - 1, adjust=False).mean()

# Avoid division by zero and handle potential inf values
rs = avg_gain / avg_loss
rs = rs.replace([np.inf, -np.inf], np.nan).fillna(0) # Replace inf with nan, then fill nan with 0

data['momentum_rsi'] = 100 - (100 / (1 + rs))


data.dropna(inplace=True)
print(f"{len(data)} days of data processed with indicators.")


# ====================================================================
# Parte 4: GERAÇÃO DAS IMAGENS E ALINHAMENTO DOS DADOS (CORRIGIDO)
# ====================================================================
print("\nGerando imagens e alinhando dados para o modelo híbrido...")

features_lstm = ['Close', 'Volume', 'volatility_bbh', 'volatility_bbl', 'volatility_bbm', 'momentum_rsi']
# O scaler é o mesmo, não precisa mudar
scaler = MinMaxScaler(feature_range=(0, 1)) # Moved scaler definition here
# data[features_lstm] = scaler.fit_transform(data[features_lstm])

# Criamos um novo dataframe para os dados normalizados para não afetar os cálculos de rótulo
data_normalized = data.copy()
data_normalized[features_lstm] = scaler.fit_transform(data[features_lstm])


image_paths, lstm_sequences, labels = [], [], []
class_names = ['ALTA', 'BAIXA', 'NEUTRA']
class_map = {name: i for i, name in enumerate(class_names)}

for i in range(len(data) - SEQ_LENGTH - FUTURE_DAYS):
    # --- Define o Rótulo (usando os dados originais, não normalizados) ---
    preco_final_janela = data['Close'].iloc[i + SEQ_LENGTH - 1]
    preco_futuro = data['Close'].iloc[i + SEQ_LENGTH + FUTURE_DAYS - 1]

    label_str = 'NEUTRA'
    # AJUSTE 1: A comparação agora é feita diretamente com os números, usando .iloc[0]
    if preco_futuro.iloc[0] > preco_final_janela.iloc[0] * (1 + THRESHOLD):
        label_str = 'ALTA'
    elif preco_futuro.iloc[0] < preco_final_janela.iloc[0] * (1 - THRESHOLD):
        label_str = 'BAIXA'
    labels.append(class_map[label_str])

    # --- Gera e Salva a Imagem (usando os dados normalizados) ---
    dados_janela_normalizados = data_normalized.iloc[i : i + SEQ_LENGTH] # Usar dados normalizados para a imagem/LSTM
    nome_arquivo = f"img_{i}.png"
    caminho_completo = os.path.join(BASE_DIR, nome_arquivo)

    fig, ax = plt.subplots(3, 1, figsize=(IMG_SIZE/100, IMG_SIZE/100), dpi=100, gridspec_kw={'height_ratios': [2, 1, 1]})
    ax[0].plot(dados_janela_normalizados['Close'].values, color='black')
    ax[0].plot(dados_janela_normalizados['volatility_bbh'].values, color='blue', alpha=0.5)
    ax[0].plot(dados_janela_normalizados['volatility_bbl'].values, color='blue', alpha=0.5)
    ax[1].plot(dados_janela_normalizados['momentum_rsi'].values, color='purple')
    ax[2].bar(range(len(dados_janela_normalizados)), dados_janela_normalizados['Volume'].values.flatten(), color='gray')
    for axis in ax: axis.axis('off')
    plt.subplots_adjust(left=0, right=1, top=1, bottom=0, hspace=0.01)
    fig.savefig(caminho_completo, bbox_inches='tight', pad_inches=0)
    plt.close(fig)

    # --- Guarda os dados alinhados (usando os dados normalizados) ---
    image_paths.append(caminho_completo)
    lstm_sequences.append(dados_janela_normalizados[features_lstm].values)

# --- Conversão e Divisão dos Dados ---
image_paths = np.array(image_paths)
lstm_sequences = np.array(lstm_sequences)
# AJUSTE 2: Mude para np.int32 para que o Keras aceite os rótulos!
labels = np.array(labels, dtype=np.int32)

print(f"Total de {len(labels)} exemplos gerados e alinhados.")

# O restante do código de divisão de dados permanece o mesmo
img_train_paths, img_val_paths, X_train_lstm, X_val_lstm, y_train, y_val = train_test_split(
    image_paths, lstm_sequences, labels, test_size=0.2, random_state=42, stratify=labels
)
print(f"Dados divididos em {len(y_train)} para treino e {len(y_val)} para validação.")


# ====================================================================
# Parte 5: CONSTRUÇÃO DO MODELO HÍBRIDO (API FUNCIONAL)
# ====================================================================
print("\nConstruindo o Cérebro Híbrido (CNN + LSTM)...")

input_cnn = Input(shape=(IMG_SIZE, IMG_SIZE, 3), name='entrada_imagem')
cnn_branch = Rescaling(1./255)(input_cnn)
cnn_branch = Conv2D(32, 3, activation='relu')(cnn_branch)
cnn_branch = MaxPooling2D()(cnn_branch)
cnn_branch = Conv2D(64, 3, activation='relu')(cnn_branch)
cnn_branch = MaxPooling2D()(cnn_branch)
cnn_branch = Flatten()(cnn_branch)
cnn_branch = Dense(64, activation='relu')(cnn_branch)

input_lstm = Input(shape=(SEQ_LENGTH, len(features_lstm)), name='entrada_numerica')
lstm_branch = LSTM(units=50)(input_lstm)
lstm_branch = Dropout(0.2)(lstm_branch)
lstm_branch = Dense(25, activation='relu')(lstm_branch)

fused = concatenate([cnn_branch, lstm_branch])
final_head = Dense(64, activation='relu')(fused)
final_head = Dropout(0.5)(final_head)
final_output = Dense(len(class_names), activation='softmax', name='saida_final')(final_head)

hybrid_model = Model(inputs=[input_cnn, input_lstm], outputs=final_output, name="Cerebro_Hibrido")
hybrid_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hybrid_model.summary()


# ====================================================================
# Parte 6: GERADOR DE DADOS E TREINAMENTO
# ====================================================================

# O gerador é definido aqui, de forma limpa e correta
def data_generator(image_paths, lstm_sequences, labels, batch_size):
    num_samples = len(image_paths)
    while True:
        indices = np.arange(num_samples)
        np.random.shuffle(indices)
        for offset in range(0, num_samples, batch_size):
            batch_indices = indices[offset:offset+batch_size]

            batch_images = np.array([img_to_array(load_img(p, target_size=(IMG_SIZE, IMG_SIZE))) for p in image_paths[batch_indices]])
            batch_lstm = lstm_sequences[batch_indices]
            batch_labels = labels[batch_indices] # Directly use the numerical labels

            print(f"Type of batch_labels before yielding: {type(batch_labels)}")
            print(f"Dtype of batch_labels before yielding: {batch_labels.dtype}")
            print(f"Shape of batch_labels before yielding: {batch_labels.shape}")


            yield ({'entrada_imagem': batch_images, 'entrada_numerica': batch_lstm},
                   batch_labels) # Yield the numerical labels as a single array


# Criando os geradores para treino e validação
train_gen = data_generator(img_train_paths, X_train_lstm, y_train, BATCH_SIZE)
val_gen = data_generator(img_val_paths, X_val_lstm, y_val, BATCH_SIZE)

print("\nIniciando o treinamento do Cérebro Híbrido...")
early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True, verbose=1)

history_hybrid = hybrid_model.fit(
    train_gen,
    steps_per_epoch=len(y_train) // BATCH_SIZE,
    validation_data=val_gen,
    validation_steps=len(y_val) // BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[early_stopping]
)


# ====================================================================
# Parte 7: AVALIAÇÃO E PREVISÃO FINAL
# ====================================================================
print("\nFazendo previsão final com o Cérebro Híbrido...")
# Preparar os dados mais recentes para a previsão
dados_recentes_nao_normalizados = yf.download(TICKER, period=f"{SEQ_LENGTH+20}d", auto_adjust=True, progress=False) # +20 para garantir dados para indicadores
dados_recentes_nao_normalizados.dropna(inplace=True)

# Recalculate indicators for recent data using Pandas Series
window = 20
dados_recentes_nao_normalizados['volatility_bbm'] = dados_recentes_nao_normalizados['Close'].rolling(window=window).mean()
dados_recentes_nao_normalizados['volatility_bbh'] = dados_recentes_nao_normalizados['Close'].rolling(window=window).mean() + dados_recentes_nao_normalizados['Close'].rolling(window=window).std() * 2
dados_recentes_nao_normalizados['volatility_bbl'] = dados_recentes_nao_normalizados['Close'].rolling(window=window).mean() - dados_recentes_nao_normalizados['Close'].rolling(window=window).std() * 2

window_rsi = 14
delta_recente = dados_recentes_nao_normalizados['Close'].diff()
gain_recente = delta_recente.where(delta_recente > 0, 0)
loss_recente = -delta_recente.where(delta_recente < 0, 0)

avg_gain_recente = gain_recente.ewm(com=13, adjust=False).mean()
avg_loss_recente = loss_recente.ewm(com=13, adjust=False).mean()

rs_recente = avg_gain_recente / avg_loss_recente
rs_recente = rs_recente.replace([np.inf, -np.inf], np.nan).fillna(0)

dados_recentes_nao_normalizados['momentum_rsi'] = 100 - (100 / (1 + rs_recente))


dados_recentes_nao_normalizados.dropna(inplace=True)


dados_recentes_normalizados = dados_recentes_nao_normalizados.copy()
dados_recentes_normalizados[features_lstm] = scaler.transform(dados_recentes_nao_normalizados[features_lstm])
dados_para_previsao = dados_recentes_normalizados.tail(SEQ_LENGTH)

# Input Numérico
X_pred_lstm = dados_para_previsao[features_lstm].values
X_pred_lstm_expanded = np.expand_dims(X_pred_lstm, 0)

# Input Visual
nome_arquivo_pred = "pred_final.png"
caminho_pred = os.path.join(BASE_DIR, nome_arquivo_pred)
fig, ax = plt.subplots(3, 1, figsize=(IMG_SIZE/100, IMG_SIZE/100), dpi=100, gridspec_kw={'height_ratios': [2, 1, 1]})
ax[0].plot(dados_para_previsao['Close'].values, color='black')
ax[0].plot(dados_para_previsao['volatility_bbh'].values, color='blue', alpha=0.5)
ax[0].plot(dados_para_previsao['volatility_bbl'].values, color='blue', alpha=0.5)
ax[1].plot(dados_para_previsao['momentum_rsi'].values, color='purple')
ax[2].bar(range(len(dados_para_previsao)), dados_para_previsao['Volume'].values.flatten(), color='gray')
for axis in ax: axis.axis('off')
plt.subplots_adjust(left=0, right=1, top=1, bottom=0, hspace=0.01)
fig.savefig(caminho_pred, bbox_inches='tight', pad_inches=0)
plt.close(fig)

img_pred = load_img(caminho_pred, target_size=(IMG_SIZE, IMG_SIZE))
img_pred_array = np.expand_dims(img_to_array(img_pred), 0)

# Fazer a previsão com os dois inputs
prediction = hybrid_model.predict({'entrada_imagem': img_pred_array, 'entrada_numerica': X_pred_lstm_expanded})
score = prediction[0]

print("\n" + "="*60)
print(f"🔮 PREDIÇÃO HÍBRIDA PARA OS PRÓXIMOS {FUTURE_DAYS} DIAS DE {TICKER}")
print("="*60)
for i, class_name in enumerate(class_names):
    print(f"Probabilidade de {class_name}: {100 * score[i]:.2f}%")

predicted_class_index = np.argmax(score)
predicted_class = class_names[predicted_class_index]
print(f"\n🟢 TENDÊNCIA MAIS PROVÁVEL: {predicted_class}")
print("="*60)
# Out:
# Instalando e importando bibliotecas...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 4.1 MB/s eta 0:00:00
# Bibliotecas carregadas com sucesso!
#
# Definindo configurações globais...
# Configurações definidas e pastas criadas.
#
# Baixando dados históricos para VALE3.SA...
# Calculating technical indicators manually using Pandas Series...
# 2616 days of data processed with indicators.
#
# Gerando imagens e alinhando dados para o modelo híbrido...
# Total de 2551 exemplos gerados e alinhados.
# Dados divididos em 2040 para treino e 511 para validação.
#
# Construindo o Cérebro Híbrido (CNN + LSTM)...
# Model: "Cerebro_Hibrido"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ entrada_imagem      │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 128, 128,  │          0 │ entrada_imagem[0… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 126, 126,  │        896 │ rescaling[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 63, 63,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 61, 61,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ entrada_numerica    │ (None, 60, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 30, 30,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 50)        │     11,400 │ entrada_numerica… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 57600)     │          0 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 50)        │          0 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │  3,686,464 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 25)        │      1,275 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 89)        │          0 │ dense[0][0],      │
# │ (Concatenate)       │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      5,760 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ saida_final (Dense) │ (None, 3)         │        195 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,724,486 (14.21 MB)
#  Trainable params: 3,724,486 (14.21 MB)
#  Non-trainable params: 0 (0.00 B)
# Iniciando o treinamento do Cérebro Híbrido...
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Epoch 1/40
#  1/63 ━━━━━━━━━━━━━━━━━━━━ 4:34 4s/step - accuracy: 0.4688 - loss: 1.0555Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  2/63 ━━━━━━━━━━━━━━━━━━━━ 40s 670ms/step - accuracy: 0.4531 - loss: 1.6039Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  3/63 ━━━━━━━━━━━━━━━━━━━━ 40s 672ms/step - accuracy: 0.4549 - loss: 1.7897Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  4/63 ━━━━━━━━━━━━━━━━━━━━ 38s 659ms/step - accuracy: 0.4447 - loss: 1.9309Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  5/63 ━━━━━━━━━━━━━━━━━━━━ 37s 652ms/step - accuracy: 0.4345 - loss: 1.9885Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  6/63 ━━━━━━━━━━━━━━━━━━━━ 37s 650ms/step - accuracy: 0.4324 - loss: 1.9926Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  7/63 ━━━━━━━━━━━━━━━━━━━━ 36s 643ms/step - accuracy: 0.4267 - loss: 1.9826Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  8/63 ━━━━━━━━━━━━━━━━━━━━ 35s 643ms/step - accuracy: 0.4242 - loss: 1.9607Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  9/63 ━━━━━━━━━━━━━━━━━━━━ 36s 673ms/step - accuracy: 0.4245 - loss: 1.9342Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 10/63 ━━━━━━━━━━━━━━━━━━━━ 38s 730ms/step - accuracy: 0.4252 - loss: 1.9065Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 11/63 ━━━━━━━━━━━━━━━━━━━━ 39s 756ms/step - accuracy: 0.4258 - loss: 1.8792Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 12/63 ━━━━━━━━━━━━━━━━━━━━ 38s 755ms/step - accuracy: 0.4261 - loss: 1.8529Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 13/63 ━━━━━━━━━━━━━━━━━━━━ 37s 747ms/step - accuracy: 0.4266 - loss: 1.8277Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 14/63 ━━━━━━━━━━━━━━━━━━━━ 36s 739ms/step - accuracy: 0.4275 - loss: 1.8036Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 15/63 ━━━━━━━━━━━━━━━━━━━━ 35s 731ms/step - accuracy: 0.4288 - loss: 1.7809Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 16/63 ━━━━━━━━━━━━━━━━━━━━ 34s 727ms/step - accuracy: 0.4300 - loss: 1.7597Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 17/63 ━━━━━━━━━━━━━━━━━━━━ 33s 719ms/step - accuracy: 0.4317 - loss: 1.7395Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 18/63 ━━━━━━━━━━━━━━━━━━━━ 32s 715ms/step - accuracy: 0.4327 - loss: 1.7207Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 19/63 ━━━━━━━━━━━━━━━━━━━━ 31s 712ms/step - accuracy: 0.4339 - loss: 1.7028Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 20/63 ━━━━━━━━━━━━━━━━━━━━ 30s 706ms/step - accuracy: 0.4351 - loss: 1.6859Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 21/63 ━━━━━━━━━━━━━━━━━━━━ 29s 703ms/step - accuracy: 0.4363 - loss: 1.6700Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 22/63 ━━━━━━━━━━━━━━━━━━━━ 28s 699ms/step - accuracy: 0.4371 - loss: 1.6550Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 23/63 ━━━━━━━━━━━━━━━━━━━━ 27s 696ms/step - accuracy: 0.4379 - loss: 1.6407Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 24/63 ━━━━━━━━━━━━━━━━━━━━ 27s 693ms/step - accuracy: 0.4386 - loss: 1.6271Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 25/63 ━━━━━━━━━━━━━━━━━━━━ 26s 691ms/step - accuracy: 0.4394 - loss: 1.6142Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 26/63 ━━━━━━━━━━━━━━━━━━━━ 25s 689ms/step - accuracy: 0.4403 - loss: 1.6018Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 27/63 ━━━━━━━━━━━━━━━━━━━━ 24s 687ms/step - accuracy: 0.4412 - loss: 1.5900Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 28/63 ━━━━━━━━━━━━━━━━━━━━ 24s 695ms/step - accuracy: 0.4419 - loss: 1.5788Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 29/63 ━━━━━━━━━━━━━━━━━━━━ 24s 711ms/step - accuracy: 0.4426 - loss: 1.5683Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 30/63 ━━━━━━━━━━━━━━━━━━━━ 23s 721ms/step - accuracy: 0.4432 - loss: 1.5582Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 31/63 ━━━━━━━━━━━━━━━━━━━━ 23s 720ms/step - accuracy: 0.4438 - loss: 1.5485Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 32/63 ━━━━━━━━━━━━━━━━━━━━ 22s 718ms/step - accuracy: 0.4444 - loss: 1.5392Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 33/63 ━━━━━━━━━━━━━━━━━━━━ 21s 715ms/step - accuracy: 0.4451 - loss: 1.5302Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 34/63 ━━━━━━━━━━━━━━━━━━━━ 20s 713ms/step - accuracy: 0.4459 - loss: 1.5215Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 35/63 ━━━━━━━━━━━━━━━━━━━━ 19s 711ms/step - accuracy: 0.4465 - loss: 1.5132Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 36/63 ━━━━━━━━━━━━━━━━━━━━ 19s 709ms/step - accuracy: 0.4472 - loss: 1.5052Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 37/63 ━━━━━━━━━━━━━━━━━━━━ 18s 706ms/step - accuracy: 0.4478 - loss: 1.4974Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 38/63 ━━━━━━━━━━━━━━━━━━━━ 17s 704ms/step - accuracy: 0.4485 - loss: 1.4900Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 39/63 ━━━━━━━━━━━━━━━━━━━━ 16s 701ms/step - accuracy: 0.4491 - loss: 1.4828Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 40/63 ━━━━━━━━━━━━━━━━━━━━ 16s 700ms/step - accuracy: 0.4497 - loss: 1.4760Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 41/63 ━━━━━━━━━━━━━━━━━━━━ 15s 698ms/step - accuracy: 0.4502 - loss: 1.4694Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 42/63 ━━━━━━━━━━━━━━━━━━━━ 14s 697ms/step - accuracy: 0.4507 - loss: 1.4630Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 43/63 ━━━━━━━━━━━━━━━━━━━━ 13s 695ms/step - accuracy: 0.4513 - loss: 1.4568Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 44/63 ━━━━━━━━━━━━━━━━━━━━ 13s 694ms/step - accuracy: 0.4518 - loss: 1.4509Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 45/63 ━━━━━━━━━━━━━━━━━━━━ 12s 693ms/step - accuracy: 0.4522 - loss: 1.4451Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 46/63 ━━━━━━━━━━━━━━━━━━━━ 11s 693ms/step - accuracy: 0.4527 - loss: 1.4396Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 47/63 ━━━━━━━━━━━━━━━━━━━━ 11s 699ms/step - accuracy: 0.4531 - loss: 1.4342Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 48/63 ━━━━━━━━━━━━━━━━━━━━ 10s 707ms/step - accuracy: 0.4536 - loss: 1.4290Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 49/63 ━━━━━━━━━━━━━━━━━━━━ 9s 712ms/step - accuracy: 0.4540 - loss: 1.4240 Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 50/63 ━━━━━━━━━━━━━━━━━━━━ 9s 711ms/step - accuracy: 0.4544 - loss: 1.4191Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 51/63 ━━━━━━━━━━━━━━━━━━━━ 8s 709ms/step - accuracy: 0.4547 - loss: 1.4144Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 52/63 ━━━━━━━━━━━━━━━━━━━━ 7s 707ms/step - accuracy: 0.4551 - loss: 1.4098Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 53/63 ━━━━━━━━━━━━━━━━━━━━ 7s 706ms/step - accuracy: 0.4555 - loss: 1.4053Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 54/63 ━━━━━━━━━━━━━━━━━━━━ 6s 705ms/step - accuracy: 0.4559 - loss: 1.4009Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 55/63 ━━━━━━━━━━━━━━━━━━━━ 5s 703ms/step - accuracy: 0.4564 - loss: 1.3966Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 56/63 ━━━━━━━━━━━━━━━━━━━━ 4s 702ms/step - accuracy: 0.4567 - loss: 1.3925Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 57/63 ━━━━━━━━━━━━━━━━━━━━ 4s 701ms/step - accuracy: 0.4570 - loss: 1.3885Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 58/63 ━━━━━━━━━━━━━━━━━━━━ 3s 700ms/step - accuracy: 0.4574 - loss: 1.3846Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 59/63 ━━━━━━━━━━━━━━━━━━━━ 2s 698ms/step - accuracy: 0.4577 - loss: 1.3808Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 60/63 ━━━━━━━━━━━━━━━━━━━━ 2s 697ms/step - accuracy: 0.4580 - loss: 1.3771Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 61/63 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step - accuracy: 0.4583 - loss: 1.3735Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.4586 - loss: 1.3699Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (24,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 694ms/step - accuracy: 0.4589 - loss: 1.3664Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (31,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 770ms/step - accuracy: 0.4592 - loss: 1.3630 - val_accuracy: 0.5021 - val_loss: 1.0269
# Epoch 2/40
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  1/63 ━━━━━━━━━━━━━━━━━━━━ 30s 490ms/step - accuracy: 0.5417 - loss: 1.0177Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  2/63 ━━━━━━━━━━━━━━━━━━━━ 38s 624ms/step - accuracy: 0.5744 - loss: 0.9963Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  3/63 ━━━━━━━━━━━━━━━━━━━━ 38s 637ms/step - accuracy: 0.5761 - loss: 0.9917Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  4/63 ━━━━━━━━━━━━━━━━━━━━ 38s 646ms/step - accuracy: 0.5758 - loss: 0.9906Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  5/63 ━━━━━━━━━━━━━━━━━━━━ 36s 636ms/step - accuracy: 0.5659 - loss: 0.9973Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  6/63 ━━━━━━━━━━━━━━━━━━━━ 36s 642ms/step - accuracy: 0.5595 - loss: 1.0021Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  7/63 ━━━━━━━━━━━━━━━━━━━━ 35s 639ms/step - accuracy: 0.5536 - loss: 1.0062Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  8/63 ━━━━━━━━━━━━━━━━━━━━ 35s 641ms/step - accuracy: 0.5489 - loss: 1.0097Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  9/63 ━━━━━━━━━━━━━━━━━━━━ 34s 645ms/step - accuracy: 0.5467 - loss: 1.0109Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 10/63 ━━━━━━━━━━━━━━━━━━━━ 34s 644ms/step - accuracy: 0.5446 - loss: 1.0119Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 11/63 ━━━━━━━━━━━━━━━━━━━━ 33s 641ms/step - accuracy: 0.5416 - loss: 1.0137Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 12/63 ━━━━━━━━━━━━━━━━━━━━ 32s 641ms/step - accuracy: 0.5394 - loss: 1.0147Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 13/63 ━━━━━━━━━━━━━━━━━━━━ 32s 641ms/step - accuracy: 0.5375 - loss: 1.0156Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 14/63 ━━━━━━━━━━━━━━━━━━━━ 31s 643ms/step - accuracy: 0.5357 - loss: 1.0166Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 15/63 ━━━━━━━━━━━━━━━━━━━━ 30s 643ms/step - accuracy: 0.5339 - loss: 1.0175Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 16/63 ━━━━━━━━━━━━━━━━━━━━ 30s 658ms/step - accuracy: 0.5327 - loss: 1.0179Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 17/63 ━━━━━━━━━━━━━━━━━━━━ 31s 687ms/step - accuracy: 0.5315 - loss: 1.0184Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 18/63 ━━━━━━━━━━━━━━━━━━━━ 31s 706ms/step - accuracy: 0.5307 - loss: 1.0188Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 19/63 ━━━━━━━━━━━━━━━━━━━━ 31s 711ms/step - accuracy: 0.5298 - loss: 1.0193Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 20/63 ━━━━━━━━━━━━━━━━━━━━ 30s 708ms/step - accuracy: 0.5292 - loss: 1.0196Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 21/63 ━━━━━━━━━━━━━━━━━━━━ 29s 714ms/step - accuracy: 0.5284 - loss: 1.0203Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 22/63 ━━━━━━━━━━━━━━━━━━━━ 29s 729ms/step - accuracy: 0.5273 - loss: 1.0210Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 23/63 ━━━━━━━━━━━━━━━━━━━━ 29s 747ms/step - accuracy: 0.5263 - loss: 1.0215Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 24/63 ━━━━━━━━━━━━━━━━━━━━ 29s 750ms/step - accuracy: 0.5256 - loss: 1.0219Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 25/63 ━━━━━━━━━━━━━━━━━━━━ 28s 746ms/step - accuracy: 0.5247 - loss: 1.0221Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 26/63 ━━━━━━━━━━━━━━━━━━━━ 27s 741ms/step - accuracy: 0.5238 - loss: 1.0223Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 27/63 ━━━━━━━━━━━━━━━━━━━━ 26s 738ms/step - accuracy: 0.5229 - loss: 1.0227Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 28/63 ━━━━━━━━━━━━━━━━━━━━ 25s 733ms/step - accuracy: 0.5220 - loss: 1.0230Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 29/63 ━━━━━━━━━━━━━━━━━━━━ 24s 729ms/step - accuracy: 0.5214 - loss: 1.0231Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 30/63 ━━━━━━━━━━━━━━━━━━━━ 23s 725ms/step - accuracy: 0.5208 - loss: 1.0232Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 31/63 ━━━━━━━━━━━━━━━━━━━━ 23s 720ms/step - accuracy: 0.5204 - loss: 1.0232Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 32/63 ━━━━━━━━━━━━━━━━━━━━ 22s 719ms/step - accuracy: 0.5200 - loss: 1.0231Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 33/63 ━━━━━━━━━━━━━━━━━━━━ 21s 723ms/step - accuracy: 0.5198 - loss: 1.0230Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 34/63 ━━━━━━━━━━━━━━━━━━━━ 21s 731ms/step - accuracy: 0.5195 - loss: 1.0229Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 35/63 ━━━━━━━━━━━━━━━━━━━━ 20s 740ms/step - accuracy: 0.5194 - loss: 1.0227Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 36/63 ━━━━━━━━━━━━━━━━━━━━ 20s 744ms/step - accuracy: 0.5192 - loss: 1.0225Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 37/63 ━━━━━━━━━━━━━━━━━━━━ 19s 741ms/step - accuracy: 0.5190 - loss: 1.0223Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 38/63 ━━━━━━━━━━━━━━━━━━━━ 18s 738ms/step - accuracy: 0.5188 - loss: 1.0223Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 39/63 ━━━━━━━━━━━━━━━━━━━━ 17s 736ms/step - accuracy: 0.5186 - loss: 1.0223Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 40/63 ━━━━━━━━━━━━━━━━━━━━ 16s 733ms/step - accuracy: 0.5183 - loss: 1.0223Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 41/63 ━━━━━━━━━━━━━━━━━━━━ 16s 730ms/step - accuracy: 0.5180 - loss: 1.0225Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 42/63 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.5177 - loss: 1.0226Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 43/63 ━━━━━━━━━━━━━━━━━━━━ 14s 726ms/step - accuracy: 0.5173 - loss: 1.0227Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 44/63 ━━━━━━━━━━━━━━━━━━━━ 13s 724ms/step - accuracy: 0.5170 - loss: 1.0228Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 45/63 ━━━━━━━━━━━━━━━━━━━━ 12s 722ms/step - accuracy: 0.5166 - loss: 1.0230Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 46/63 ━━━━━━━━━━━━━━━━━━━━ 12s 720ms/step - accuracy: 0.5163 - loss: 1.0232Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 47/63 ━━━━━━━━━━━━━━━━━━━━ 11s 718ms/step - accuracy: 0.5160 - loss: 1.0233Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 48/63 ━━━━━━━━━━━━━━━━━━━━ 10s 716ms/step - accuracy: 0.5156 - loss: 1.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 49/63 ━━━━━━━━━━━━━━━━━━━━ 10s 714ms/step - accuracy: 0.5153 - loss: 1.0237Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 50/63 ━━━━━━━━━━━━━━━━━━━━ 9s 713ms/step - accuracy: 0.5149 - loss: 1.0238 Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 51/63 ━━━━━━━━━━━━━━━━━━━━ 8s 711ms/step - accuracy: 0.5146 - loss: 1.0240Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 52/63 ━━━━━━━━━━━━━━━━━━━━ 7s 713ms/step - accuracy: 0.5143 - loss: 1.0241Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 53/63 ━━━━━━━━━━━━━━━━━━━━ 7s 720ms/step - accuracy: 0.5140 - loss: 1.0242Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 54/63 ━━━━━━━━━━━━━━━━━━━━ 6s 724ms/step - accuracy: 0.5137 - loss: 1.0243Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 55/63 ━━━━━━━━━━━━━━━━━━━━ 5s 726ms/step - accuracy: 0.5134 - loss: 1.0245Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 56/63 ━━━━━━━━━━━━━━━━━━━━ 5s 725ms/step - accuracy: 0.5131 - loss: 1.0246Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 57/63 ━━━━━━━━━━━━━━━━━━━━ 4s 723ms/step - accuracy: 0.5128 - loss: 1.0247Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 58/63 ━━━━━━━━━━━━━━━━━━━━ 3s 721ms/step - accuracy: 0.5126 - loss: 1.0248Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 59/63 ━━━━━━━━━━━━━━━━━━━━ 2s 720ms/step - accuracy: 0.5123 - loss: 1.0249Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 60/63 ━━━━━━━━━━━━━━━━━━━━ 2s 718ms/step - accuracy: 0.5121 - loss: 1.0250Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 61/63 ━━━━━━━━━━━━━━━━━━━━ 1s 717ms/step - accuracy: 0.5118 - loss: 1.0251Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 716ms/step - accuracy: 0.5116 - loss: 1.0252Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 715ms/step - accuracy: 0.5113 - loss: 1.0253Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.5111 - loss: 1.0254 - val_accuracy: 0.4958 - val_loss: 1.0194
# Epoch 3/40
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (24,)
#  1/63 ━━━━━━━━━━━━━━━━━━━━ 38s 614ms/step - accuracy: 0.4688 - loss: 1.0541Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  2/63 ━━━━━━━━━━━━━━━━━━━━ 30s 495ms/step - accuracy: 0.4754 - loss: 1.0527Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  3/63 ━━━━━━━━━━━━━━━━━━━━ 33s 552ms/step - accuracy: 0.4874 - loss: 1.0422Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  4/63 ━━━━━━━━━━━━━━━━━━━━ 33s 576ms/step - accuracy: 0.4843 - loss: 1.0418Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  5/63 ━━━━━━━━━━━━━━━━━━━━ 34s 591ms/step - accuracy: 0.4875 - loss: 1.0378Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  6/63 ━━━━━━━━━━━━━━━━━━━━ 33s 594ms/step - accuracy: 0.4850 - loss: 1.0368Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  7/63 ━━━━━━━━━━━━━━━━━━━━ 35s 632ms/step - accuracy: 0.4838 - loss: 1.0347Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  8/63 ━━━━━━━━━━━━━━━━━━━━ 37s 690ms/step - accuracy: 0.4823 - loss: 1.0339Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  9/63 ━━━━━━━━━━━━━━━━━━━━ 39s 736ms/step - accuracy: 0.4803 - loss: 1.0334Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 10/63 ━━━━━━━━━━━━━━━━━━━━ 39s 747ms/step - accuracy: 0.4791 - loss: 1.0337Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 11/63 ━━━━━━━━━━━━━━━━━━━━ 38s 733ms/step - accuracy: 0.4786 - loss: 1.0331Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 12/63 ━━━━━━━━━━━━━━━━━━━━ 36s 723ms/step - accuracy: 0.4791 - loss: 1.0317Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 13/63 ━━━━━━━━━━━━━━━━━━━━ 35s 714ms/step - accuracy: 0.4786 - loss: 1.0309Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 14/63 ━━━━━━━━━━━━━━━━━━━━ 34s 705ms/step - accuracy: 0.4780 - loss: 1.0303Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 15/63 ━━━━━━━━━━━━━━━━━━━━ 33s 697ms/step - accuracy: 0.4778 - loss: 1.0299Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 16/63 ━━━━━━━━━━━━━━━━━━━━ 32s 693ms/step - accuracy: 0.4777 - loss: 1.0290Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 17/63 ━━━━━━━━━━━━━━━━━━━━ 31s 690ms/step - accuracy: 0.4777 - loss: 1.0285Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 18/63 ━━━━━━━━━━━━━━━━━━━━ 30s 686ms/step - accuracy: 0.4782 - loss: 1.0276Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 19/63 ━━━━━━━━━━━━━━━━━━━━ 29s 682ms/step - accuracy: 0.4789 - loss: 1.0267Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 20/63 ━━━━━━━━━━━━━━━━━━━━ 29s 678ms/step - accuracy: 0.4797 - loss: 1.0257Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 21/63 ━━━━━━━━━━━━━━━━━━━━ 28s 678ms/step - accuracy: 0.4802 - loss: 1.0248Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 22/63 ━━━━━━━━━━━━━━━━━━━━ 27s 677ms/step - accuracy: 0.4808 - loss: 1.0240Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 23/63 ━━━━━━━━━━━━━━━━━━━━ 26s 675ms/step - accuracy: 0.4810 - loss: 1.0233Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 24/63 ━━━━━━━━━━━━━━━━━━━━ 26s 673ms/step - accuracy: 0.4813 - loss: 1.0227Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 25/63 ━━━━━━━━━━━━━━━━━━━━ 25s 671ms/step - accuracy: 0.4816 - loss: 1.0222Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 26/63 ━━━━━━━━━━━━━━━━━━━━ 24s 674ms/step - accuracy: 0.4820 - loss: 1.0216Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 27/63 ━━━━━━━━━━━━━━━━━━━━ 24s 688ms/step - accuracy: 0.4823 - loss: 1.0210Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 28/63 ━━━━━━━━━━━━━━━━━━━━ 24s 701ms/step - accuracy: 0.4827 - loss: 1.0205Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 29/63 ━━━━━━━━━━━━━━━━━━━━ 24s 706ms/step - accuracy: 0.4832 - loss: 1.0200Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 30/63 ━━━━━━━━━━━━━━━━━━━━ 23s 702ms/step - accuracy: 0.4837 - loss: 1.0194Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 31/63 ━━━━━━━━━━━━━━━━━━━━ 22s 700ms/step - accuracy: 0.4842 - loss: 1.0188Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 32/63 ━━━━━━━━━━━━━━━━━━━━ 21s 698ms/step - accuracy: 0.4846 - loss: 1.0182Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 33/63 ━━━━━━━━━━━━━━━━━━━━ 20s 695ms/step - accuracy: 0.4851 - loss: 1.0176Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 34/63 ━━━━━━━━━━━━━━━━━━━━ 20s 693ms/step - accuracy: 0.4856 - loss: 1.0170Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 35/63 ━━━━━━━━━━━━━━━━━━━━ 19s 691ms/step - accuracy: 0.4861 - loss: 1.0163Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 36/63 ━━━━━━━━━━━━━━━━━━━━ 18s 689ms/step - accuracy: 0.4867 - loss: 1.0156Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 37/63 ━━━━━━━━━━━━━━━━━━━━ 17s 688ms/step - accuracy: 0.4871 - loss: 1.0150Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 38/63 ━━━━━━━━━━━━━━━━━━━━ 17s 686ms/step - accuracy: 0.4876 - loss: 1.0144Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 39/63 ━━━━━━━━━━━━━━━━━━━━ 16s 684ms/step - accuracy: 0.4880 - loss: 1.0138Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 40/63 ━━━━━━━━━━━━━━━━━━━━ 15s 683ms/step - accuracy: 0.4884 - loss: 1.0133Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 41/63 ━━━━━━━━━━━━━━━━━━━━ 14s 681ms/step - accuracy: 0.4889 - loss: 1.0128Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 42/63 ━━━━━━━━━━━━━━━━━━━━ 14s 680ms/step - accuracy: 0.4893 - loss: 1.0122Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 43/63 ━━━━━━━━━━━━━━━━━━━━ 13s 678ms/step - accuracy: 0.4896 - loss: 1.0117Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 44/63 ━━━━━━━━━━━━━━━━━━━━ 12s 677ms/step - accuracy: 0.4900 - loss: 1.0113Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 45/63 ━━━━━━━━━━━━━━━━━━━━ 12s 677ms/step - accuracy: 0.4904 - loss: 1.0108Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# ...
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  6/63 ━━━━━━━━━━━━━━━━━━━━ 36s 643ms/step - accuracy: 0.9875 - loss: 0.0274Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  7/63 ━━━━━━━━━━━━━━━━━━━━ 37s 668ms/step - accuracy: 0.9880 - loss: 0.0266Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  8/63 ━━━━━━━━━━━━━━━━━━━━ 39s 719ms/step - accuracy: 0.9880 - loss: 0.0267Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
#  9/63 ━━━━━━━━━━━━━━━━━━━━ 41s 760ms/step - accuracy: 0.9882 - loss: 0.0265Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (24,)
# 10/63 ━━━━━━━━━━━━━━━━━━━━ 41s 781ms/step - accuracy: 0.9885 - loss: 0.0263Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 11/63 ━━━━━━━━━━━━━━━━━━━━ 39s 752ms/step - accuracy: 0.9887 - loss: 0.0260Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 12/63 ━━━━━━━━━━━━━━━━━━━━ 37s 743ms/step - accuracy: 0.9890 - loss: 0.0256Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 13/63 ━━━━━━━━━━━━━━━━━━━━ 36s 735ms/step - accuracy: 0.9893 - loss: 0.0252Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 14/63 ━━━━━━━━━━━━━━━━━━━━ 35s 728ms/step - accuracy: 0.9895 - loss: 0.0248Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 15/63 ━━━━━━━━━━━━━━━━━━━━ 34s 721ms/step - accuracy: 0.9898 - loss: 0.0244Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 16/63 ━━━━━━━━━━━━━━━━━━━━ 33s 716ms/step - accuracy: 0.9901 - loss: 0.0240Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 17/63 ━━━━━━━━━━━━━━━━━━━━ 32s 712ms/step - accuracy: 0.9902 - loss: 0.0239Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 18/63 ━━━━━━━━━━━━━━━━━━━━ 31s 709ms/step - accuracy: 0.9904 - loss: 0.0237Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 19/63 ━━━━━━━━━━━━━━━━━━━━ 30s 704ms/step - accuracy: 0.9904 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 20/63 ━━━━━━━━━━━━━━━━━━━━ 30s 701ms/step - accuracy: 0.9905 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 21/63 ━━━━━━━━━━━━━━━━━━━━ 29s 698ms/step - accuracy: 0.9905 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 22/63 ━━━━━━━━━━━━━━━━━━━━ 28s 695ms/step - accuracy: 0.9905 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 23/63 ━━━━━━━━━━━━━━━━━━━━ 27s 693ms/step - accuracy: 0.9904 - loss: 0.0237Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 24/63 ━━━━━━━━━━━━━━━━━━━━ 26s 690ms/step - accuracy: 0.9905 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 25/63 ━━━━━━━━━━━━━━━━━━━━ 26s 689ms/step - accuracy: 0.9905 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 26/63 ━━━━━━━━━━━━━━━━━━━━ 25s 694ms/step - accuracy: 0.9905 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 27/63 ━━━━━━━━━━━━━━━━━━━━ 25s 709ms/step - accuracy: 0.9906 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 28/63 ━━━━━━━━━━━━━━━━━━━━ 25s 721ms/step - accuracy: 0.9906 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 29/63 ━━━━━━━━━━━━━━━━━━━━ 24s 727ms/step - accuracy: 0.9906 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 30/63 ━━━━━━━━━━━━━━━━━━━━ 23s 725ms/step - accuracy: 0.9906 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 31/63 ━━━━━━━━━━━━━━━━━━━━ 23s 722ms/step - accuracy: 0.9906 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 32/63 ━━━━━━━━━━━━━━━━━━━━ 22s 719ms/step - accuracy: 0.9906 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 33/63 ━━━━━━━━━━━━━━━━━━━━ 21s 718ms/step - accuracy: 0.9906 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 34/63 ━━━━━━━━━━━━━━━━━━━━ 20s 716ms/step - accuracy: 0.9906 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 35/63 ━━━━━━━━━━━━━━━━━━━━ 19s 714ms/step - accuracy: 0.9906 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 36/63 ━━━━━━━━━━━━━━━━━━━━ 19s 712ms/step - accuracy: 0.9906 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 37/63 ━━━━━━━━━━━━━━━━━━━━ 18s 710ms/step - accuracy: 0.9906 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 38/63 ━━━━━━━━━━━━━━━━━━━━ 17s 708ms/step - accuracy: 0.9906 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 39/63 ━━━━━━━━━━━━━━━━━━━━ 16s 707ms/step - accuracy: 0.9907 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 40/63 ━━━━━━━━━━━━━━━━━━━━ 16s 706ms/step - accuracy: 0.9907 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 41/63 ━━━━━━━━━━━━━━━━━━━━ 15s 704ms/step - accuracy: 0.9907 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 42/63 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9907 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 43/63 ━━━━━━━━━━━━━━━━━━━━ 14s 702ms/step - accuracy: 0.9907 - loss: 0.0234Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 44/63 ━━━━━━━━━━━━━━━━━━━━ 13s 700ms/step - accuracy: 0.9908 - loss: 0.0234Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 45/63 ━━━━━━━━━━━━━━━━━━━━ 12s 706ms/step - accuracy: 0.9908 - loss: 0.0234Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 46/63 ━━━━━━━━━━━━━━━━━━━━ 12s 713ms/step - accuracy: 0.9908 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 47/63 ━━━━━━━━━━━━━━━━━━━━ 11s 719ms/step - accuracy: 0.9908 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 48/63 ━━━━━━━━━━━━━━━━━━━━ 10s 720ms/step - accuracy: 0.9908 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 49/63 ━━━━━━━━━━━━━━━━━━━━ 10s 719ms/step - accuracy: 0.9908 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 50/63 ━━━━━━━━━━━━━━━━━━━━ 9s 717ms/step - accuracy: 0.9908 - loss: 0.0235 Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 51/63 ━━━━━━━━━━━━━━━━━━━━ 8s 715ms/step - accuracy: 0.9908 - loss: 0.0235Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 52/63 ━━━━━━━━━━━━━━━━━━━━ 7s 714ms/step - accuracy: 0.9908 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 53/63 ━━━━━━━━━━━━━━━━━━━━ 7s 713ms/step - accuracy: 0.9908 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 54/63 ━━━━━━━━━━━━━━━━━━━━ 6s 711ms/step - accuracy: 0.9908 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 55/63 ━━━━━━━━━━━━━━━━━━━━ 5s 710ms/step - accuracy: 0.9908 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 56/63 ━━━━━━━━━━━━━━━━━━━━ 4s 709ms/step - accuracy: 0.9908 - loss: 0.0236Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 57/63 ━━━━━━━━━━━━━━━━━━━━ 4s 708ms/step - accuracy: 0.9907 - loss: 0.0237Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 58/63 ━━━━━━━━━━━━━━━━━━━━ 3s 707ms/step - accuracy: 0.9907 - loss: 0.0237Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 59/63 ━━━━━━━━━━━━━━━━━━━━ 2s 706ms/step - accuracy: 0.9907 - loss: 0.0238Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 60/63 ━━━━━━━━━━━━━━━━━━━━ 2s 705ms/step - accuracy: 0.9907 - loss: 0.0239Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 61/63 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step - accuracy: 0.9907 - loss: 0.0239Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9906 - loss: 0.0240Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9906 - loss: 0.0241Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (31,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# Type of batch_labels before yielding: <class 'numpy.ndarray'>
# Dtype of batch_labels before yielding: int32
# Shape of batch_labels before yielding: (32,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 49s 769ms/step - accuracy: 0.9906 - loss: 0.0241 - val_accuracy: 0.5762 - val_loss: 2.0975
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 4.
#
# Fazendo previsão final com o Cérebro Híbrido...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
#
# ============================================================
# 🔮 PREDIÇÃO HÍBRIDA PARA OS PRÓXIMOS 5 DIAS DE VALE3.SA
# ============================================================
# Probabilidade de ALTA: 17.12%
# Probabilidade de BAIXA: 24.83%
# Probabilidade de NEUTRA: 58.05%
#
# 🟢 TENDÊNCIA MAIS PROVÁVEL: NEUTRA
# ============================================================
