# %% [markdown]
# <a href="https://colab.research.google.com/github/rondinell/Intelig-ncia-Artificial/blob/main/projetodeaplicativofuturositeinvestimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# O nome do seu arquivo Excel
caminho_arquivo = 'PROJETOdeinvestimento.xlsx'

print("--- Ferramenta de Mapeamento de Colunas ---")

try:
    # Lemos APENAS o cabeçalho do arquivo, ignorando os dados.
    # Isso nos mostrará a estrutura exata que o Python "enxerga".
    df_header = pd.read_excel(caminho_arquivo, header=[1, 2], nrows=0)

    # Agora, vamos imprimir cada par de nomes de coluna encontrado
    print("\n--- MAPA DE COLUNAS ENCONTRADO (Nome Principal, Sub-nome) ---")
    for coluna in df_header.columns:
        print(coluna)

except Exception as e:
    print(f"\nOcorreu um erro ao executar a ferramenta de diagnóstico: {e}")
    print("Isso confirma que a estrutura do arquivo é extremamente irregular.")
# Out:
# --- Ferramenta de Mapeamento de Colunas ---
#
# --- MAPA DE COLUNAS ENCONTRADO (Nome Principal, Sub-nome) ---
# ('Informações municipais', 'UF')
# ('Informações municipais', 'Município')
# ('Informações municipais', 'Código IBGE (7)')
# ('Informações municipais', 'Código IBGE (6)')
# ('Informações municipais', 'Capital')
# ('Informações municipais', 'G100')
# ('Informações municipais', 'Região')
# ('Informações municipais', 'Aglomerado')
# ('Informações municipais', 'Região imediata')
# ('Informações municipais', 'Região intermediária')
# ('Informações municipais', 'Mapa regional')
# ('Informações municipais', 'Latitude')
# ('Informações municipais', 'Longitude')
# ('Informações municipais', 'Setor econômico predominante no município')
# ('Informações municipais', 'Atividade com maior valor adicionado bruto')
# ('Informações municipais', 'Atividade com segundo maior valor adicionado bruto')
# ('Informações municipais', 'Atividade com terceiro maior valor adicionado bruto')
# ('Informações municipais', 'População')
# ('Informações municipais', 'Faixa populacional')
# ('Informações municipais', 'População urbana (Censo 2010)')
# ('Informações municipais', 'População rural (Censo 2010)')
# ('Dependência fiscal', 'Dados brutos')
# ('Dependência fiscal', 'Nota normalizada')
# ('Dependência fiscal', 'Colocação')
# ('Dependência fiscal', 'Delta colocação')
# ('Taxa de investimento', 'Dados brutos')
# ('Taxa de investimento', 'Nota normalizada')
# ('Taxa de investimento', 'Colocação')
# ('Taxa de investimento', 'Delta colocação')
# ('Despesa com pessoal', 'Dados brutos')
# ('Despesa com pessoal', 'Nota normalizada')
# ('Despesa com pessoal', 'Colocação')
# ('Despesa com pessoal', 'Delta colocação')
# ('Endividamento', 'Dados brutos')
# ('Endividamento', 'Nota normalizada')
# ('Endividamento', 'Colocação')
# ('Endividamento', 'Delta colocação')
# ('Custo da função administrativa', 'Dados brutos')
# ('Custo da função administrativa', 'Nota normalizada')
# ('Custo da função administrativa', 'Colocação')
# ('Custo da função administrativa', 'Delta colocação')
# ('Custo da função legislativa', 'Dados brutos')
# ('Custo da função legislativa', 'Nota normalizada')
# ('Custo da função legislativa', 'Colocação')
# ('Custo da função legislativa', 'Delta colocação')
# ('Qualidade da informação contábil e fiscal', 'Dados brutos')
# ('Qualidade da informação contábil e fiscal', 'Nota normalizada')
# ('Qualidade da informação contábil e fiscal', 'Colocação')
# ('Qualidade da informação contábil e fiscal', 'Delta colocação')
# ('Tempo para abertura de empresas', 'Dados brutos')
# ('Tempo para abertura de empresas', 'Nota normalizada')
# ('Tempo para abertura de empresas', 'Colocação')
# ('Tempo para abertura de empresas', 'Delta colocação')
# ('Qualificação do servidor', 'Dados brutos')
# ('Qualificação do servidor', 'Nota normalizada')
# ('Qualificação do servidor', 'Colocação')
# ('Qualificação do servidor', 'Delta colocação')
# ('Transparência municipal', 'Dados brutos')
# ('Transparência municipal', 'Nota normalizada')
# ('Transparência municipal', 'Colocação')
# ('Transparência municipal', 'Delta colocação')
# ('Cobertura da atenção primária', 'Dados brutos')
# ('Cobertura da atenção primária', 'Nota normalizada')
# ('Cobertura da atenção primária', 'Colocação')
# ('Cobertura da atenção primária', 'Delta colocação')
# ('Cobertura de saúde suplementar', 'Dados brutos')
# ('Cobertura de saúde suplementar', 'Nota normalizada')
# ('Cobertura de saúde suplementar', 'Colocação')
# ('Cobertura de saúde suplementar', 'Delta colocação')
# ('Cobertura vacinal', 'Dados brutos')
# ('Cobertura vacinal', 'Nota normalizada')
# ('Cobertura vacinal', 'Colocação')
# ('Cobertura vacinal', 'Delta colocação')
# ('Atendimento pré-natal', 'Dados brutos')
# ('Atendimento pré-natal', 'Nota normalizada')
# ('Atendimento pré-natal', 'Colocação')
# ('Atendimento pré-natal', 'Delta colocação')
# ('Mortalidade materna', 'Dados brutos')
# ('Mortalidade materna', 'Nota normalizada')
# ('Mortalidade materna', 'Colocação')
# ('Mortalidade materna', 'Delta colocação')
# ('Desnutrição na infância', 'Dados brutos')
# ('Desnutrição na infância', 'Nota normalizada')
# ('Desnutrição na infância', 'Colocação')
# ('Desnutrição na infância', 'Delta colocação')
# ('Obesidade na infância', 'Dados brutos')
# ('Obesidade na infância', 'Nota normalizada')
# ('Obesidade na infância', 'Colocação')
# ('Obesidade na infância', 'Delta colocação')
# ('Mortalidade na infância', 'Dados brutos')
# ('Mortalidade na infância', 'Nota normalizada')
# ('Mortalidade na infância', 'Colocação')
# ('Mortalidade na infância', 'Delta colocação')
# ('Mortalidade por causas evitáveis', 'Dados brutos')
# ('Mortalidade por causas evitáveis', 'Nota normalizada')
# ('Mortalidade por causas evitáveis', 'Colocação')
# ('Mortalidade por causas evitáveis', 'Delta colocação')
# ('Taxa de atendimento - Educação infantil', 'Dados brutos')
# ('Taxa de atendimento - Educação infantil', 'Nota normalizada')
# ('Taxa de atendimento - Educação infantil', 'Colocação')
# ('Taxa de atendimento - Educação infantil', 'Delta colocação')
# ('Taxa líquida de matrícula - Ensino fundamental', 'Dados brutos')
# ('Taxa líquida de matrícula - Ensino fundamental', 'Nota normalizada')
# ('Taxa líquida de matrícula - Ensino fundamental', 'Colocação')
# ('Taxa líquida de matrícula - Ensino fundamental', 'Delta colocação')
# ('Taxa líquida de matrícula - Ensino médio', 'Dados brutos')
# ('Taxa líquida de matrícula - Ensino médio', 'Nota normalizada')
# ('Taxa líquida de matrícula - Ensino médio', 'Colocação')
# ('Taxa líquida de matrícula - Ensino médio', 'Delta colocação')
# ('Alunos em tempo integral - Educação infantil', 'Dados brutos')
# ('Alunos em tempo integral - Educação infantil', 'Nota normalizada')
# ('Alunos em tempo integral - Educação infantil', 'Colocação')
# ('Alunos em tempo integral - Educação infantil', 'Delta colocação')
# ('Alunos em tempo integral - Ensino fundamental', 'Dados brutos')
# ('Alunos em tempo integral - Ensino fundamental', 'Nota normalizada')
# ('Alunos em tempo integral - Ensino fundamental', 'Colocação')
# ('Alunos em tempo integral - Ensino fundamental', 'Delta colocação')
# ('Alunos em tempo integral - Ensino médio', 'Dados brutos')
# ('Alunos em tempo integral - Ensino médio', 'Nota normalizada')
# ('Alunos em tempo integral - Ensino médio', 'Colocação')
# ('Alunos em tempo integral - Ensino médio', 'Delta colocação')
# ('IDEB - Ensino fundamental anos iniciais', 'Dados brutos')
# ('IDEB - Ensino fundamental anos iniciais', 'Nota normalizada')
# ('IDEB - Ensino fundamental anos iniciais', 'Colocação')
# ('IDEB - Ensino fundamental anos iniciais', 'Delta colocação')
# ('IDEB - Ensino fundamental anos finais', 'Dados brutos')
# ('IDEB - Ensino fundamental anos finais', 'Nota normalizada')
# ('IDEB - Ensino fundamental anos finais', 'Colocação')
# ('IDEB - Ensino fundamental anos finais', 'Delta colocação')
# ('IDEB - Ensino médio', 'Dados brutos')
# ('IDEB - Ensino médio', 'Nota normalizada')
# ('IDEB - Ensino médio', 'Colocação')
# ('IDEB - Ensino médio', 'Delta colocação')
# ('ENEM', 'Dados brutos')
# ('ENEM', 'Nota normalizada')
# ('ENEM', 'Colocação')
# ('ENEM', 'Delta colocação')
# ('Mortes violentas intencionais', 'Dados brutos')
# ('Mortes violentas intencionais', 'Nota normalizada')
# ('Mortes violentas intencionais', 'Colocação')
# ('Mortes violentas intencionais', 'Delta colocação')
# ('Mortes por causas indeterminadas', 'Dados brutos')
# ('Mortes por causas indeterminadas', 'Nota normalizada')
# ('Mortes por causas indeterminadas', 'Colocação')
# ('Mortes por causas indeterminadas', 'Delta colocação')
# ('Mortalidade de jovens por razões de segurança', 'Dados brutos')
# ('Mortalidade de jovens por razões de segurança', 'Nota normalizada')
# ('Mortalidade de jovens por razões de segurança', 'Colocação')
# ('Mortalidade de jovens por razões de segurança', 'Delta colocação')
# ('Mortalidade nos transportes', 'Dados brutos')
# ('Mortalidade nos transportes', 'Nota normalizada')
# ('Mortalidade nos transportes', 'Colocação')
# ('Mortalidade nos transportes', 'Delta colocação')
# ('Morbidade nos transportes', 'Dados brutos')
# ('Morbidade nos transportes', 'Nota normalizada')
# ('Morbidade nos transportes', 'Colocação')
# ('Morbidade nos transportes', 'Delta colocação')
# ('Cobertura do abastecimento de água', 'Dados brutos')
# ('Cobertura do abastecimento de água', 'Nota normalizada')
# ('Cobertura do abastecimento de água', 'Colocação')
# ('Cobertura do abastecimento de água', 'Delta colocação')
# ('Perdas na distribuição de água', 'Dados brutos')
# ('Perdas na distribuição de água', 'Nota normalizada')
# ('Perdas na distribuição de água', 'Colocação')
# ('Perdas na distribuição de água', 'Delta colocação')
# ('Perdas no faturamento de água', 'Dados brutos')
# ('Perdas no faturamento de água', 'Nota normalizada')
# ('Perdas no faturamento de água', 'Colocação')
# ('Perdas no faturamento de água', 'Delta colocação')
# ('Cobertura da coleta de esgoto', 'Dados brutos')
# ('Cobertura da coleta de esgoto', 'Nota normalizada')
# ('Cobertura da coleta de esgoto', 'Colocação')
# ('Cobertura da coleta de esgoto', 'Delta colocação')
# ('Cobertura do tratamento de esgoto', 'Dados brutos')
# ('Cobertura do tratamento de esgoto', 'Nota normalizada')
# ('Cobertura do tratamento de esgoto', 'Colocação')
# ('Cobertura do tratamento de esgoto', 'Delta colocação')
# ('Cobertura da coleta de resíduos domésticos', 'Dados brutos')
# ('Cobertura da coleta de resíduos domésticos', 'Nota normalizada')
# ('Cobertura da coleta de resíduos domésticos', 'Colocação')
# ('Cobertura da coleta de resíduos domésticos', 'Delta colocação')
# ('Destinação do lixo', 'Dados brutos')
# ('Destinação do lixo', 'Nota normalizada')
# ('Destinação do lixo', 'Colocação')
# ('Destinação do lixo', 'Delta colocação')
# ('Emissões de gases de efeito estufa', 'Dados brutos')
# ('Emissões de gases de efeito estufa', 'Nota normalizada')
# ('Emissões de gases de efeito estufa', 'Colocação')
# ('Emissões de gases de efeito estufa', 'Delta colocação')
# ('Cobertura de floresta natural', 'Dados brutos')
# ('Cobertura de floresta natural', 'Nota normalizada')
# ('Cobertura de floresta natural', 'Colocação')
# ('Cobertura de floresta natural', 'Delta colocação')
# ('Desmatamento ilegal', 'Dados brutos')
# ('Desmatamento ilegal', 'Nota normalizada')
# ('Desmatamento ilegal', 'Colocação')
# ('Desmatamento ilegal', 'Delta colocação')
# ('Velocidade do desmatamento ilegal', 'Dados brutos')
# ('Velocidade do desmatamento ilegal', 'Nota normalizada')
# ('Velocidade do desmatamento ilegal', 'Colocação')
# ('Velocidade do desmatamento ilegal', 'Delta colocação')
# ('Áreas recuperadas', 'Dados brutos')
# ('Áreas recuperadas', 'Nota normalizada')
# ('Áreas recuperadas', 'Colocação')
# ('Áreas recuperadas', 'Delta colocação')
# ('População vulnerável', 'Dados brutos')
# ('População vulnerável', 'Nota normalizada')
# ('População vulnerável', 'Colocação')
# ('População vulnerável', 'Delta colocação')
# ('Formalidade no mercado de trabalho', 'Dados brutos')
# ('Formalidade no mercado de trabalho', 'Nota normalizada')
# ('Formalidade no mercado de trabalho', 'Colocação')
# ('Formalidade no mercado de trabalho', 'Delta colocação')
# ('Crescimento dos empregos formais', 'Dados brutos')
# ('Crescimento dos empregos formais', 'Nota normalizada')
# ('Crescimento dos empregos formais', 'Colocação')
# ('Crescimento dos empregos formais', 'Delta colocação')
# ('Recursos para pesquisa e desenvolvimento científico', 'Dados brutos')
# ('Recursos para pesquisa e desenvolvimento científico', 'Nota normalizada')
# ('Recursos para pesquisa e desenvolvimento científico', 'Colocação')
# ('Recursos para pesquisa e desenvolvimento científico', 'Delta colocação')
# ('Empregos no setor criativo', 'Dados brutos')
# ('Empregos no setor criativo', 'Nota normalizada')
# ('Empregos no setor criativo', 'Colocação')
# ('Empregos no setor criativo', 'Delta colocação')
# ('Crédito per capita', 'Dados brutos')
# ('Crédito per capita', 'Nota normalizada')
# ('Crédito per capita', 'Colocação')
# ('Crédito per capita', 'Delta colocação')
# ('PIB per capita', 'Dados brutos')
# ('PIB per capita', 'Nota normalizada')
# ('PIB per capita', 'Colocação')
# ('PIB per capita', 'Delta colocação')
# ('Crescimento do PIB per capita', 'Dados brutos')
# ('Crescimento do PIB per capita', 'Nota normalizada')
# ('Crescimento do PIB per capita', 'Colocação')
# ('Crescimento do PIB per capita', 'Delta colocação')
# ('Complexidade econômica', 'Dados brutos')
# ('Complexidade econômica', 'Nota normalizada')
# ('Complexidade econômica', 'Colocação')
# ('Complexidade econômica', 'Delta colocação')
# ('Renda média do trabalho formal', 'Dados brutos')
# ('Renda média do trabalho formal', 'Nota normalizada')
# ('Renda média do trabalho formal', 'Colocação')
# ('Renda média do trabalho formal', 'Delta colocação')
# ('Crescimento da renda média do trabalho formal', 'Dados brutos')
# ('Crescimento da renda média do trabalho formal', 'Nota normalizada')
# ('Crescimento da renda média do trabalho formal', 'Colocação')
# ('Crescimento da renda média do trabalho formal', 'Delta colocação')
# ('Taxa bruta de matrícula - Ensino técnico e profissionalizante', 'Dados brutos')
# ('Taxa bruta de matrícula - Ensino técnico e profissionalizante', 'Nota normalizada')
# ('Taxa bruta de matrícula - Ensino técnico e profissionalizante', 'Colocação')
# ('Taxa bruta de matrícula - Ensino técnico e profissionalizante', 'Delta colocação')
# ('Taxa bruta de matrícula - Ensino superior', 'Dados brutos')
# ('Taxa bruta de matrícula - Ensino superior', 'Nota normalizada')
# ('Taxa bruta de matrícula - Ensino superior', 'Colocação')
# ('Taxa bruta de matrícula - Ensino superior', 'Delta colocação')
# ('Qualificação dos trabalhadores em emprego formal', 'Dados brutos')
# ('Qualificação dos trabalhadores em emprego formal', 'Nota normalizada')
# ('Qualificação dos trabalhadores em emprego formal', 'Colocação')
# ('Qualificação dos trabalhadores em emprego formal', 'Delta colocação')
# ('Acessos de telefonia móvel ', 'Dados brutos')
# ('Acessos de telefonia móvel ', 'Nota normalizada')
# ('Acessos de telefonia móvel ', 'Colocação')
# ('Acessos de telefonia móvel ', 'Delta colocação')
# ('Acessos de telefonia móvel - 4G', 'Dados brutos')
# ('Acessos de telefonia móvel - 4G', 'Nota normalizada')
# ('Acessos de telefonia móvel - 4G', 'Colocação')
# ('Acessos de telefonia móvel - 4G', 'Delta colocação')
# ('Acessos de banda larga', 'Dados brutos')
# ('Acessos de banda larga', 'Nota normalizada')
# ('Acessos de banda larga', 'Colocação')
# ('Acessos de banda larga', 'Delta colocação')
# ('Acessos de banda larga - Fibra ótica', 'Dados brutos')
# ('Acessos de banda larga - Fibra ótica', 'Nota normalizada')
# ('Acessos de banda larga - Fibra ótica', 'Colocação')
# ('Acessos de banda larga - Fibra ótica', 'Delta colocação')
# ('Acessos de banda larga - Alta velocidade', 'Dados brutos')
# ('Acessos de banda larga - Alta velocidade', 'Nota normalizada')
# ('Acessos de banda larga - Alta velocidade', 'Colocação')
# ('Acessos de banda larga - Alta velocidade', 'Delta colocação')

# %%
# -*- coding: utf-8 -*-
# Importa a biblioteca pandas para análise de dados
import pandas as pd

def gerar_ranking_cidades_excel(caminho_arquivo_excel, numero_cidades):
    """
    Lê um arquivo Excel de dados de cidades, calcula um ranking com base na
    soma das colocações e exibe as melhores classificadas.

    Argumentos:
    caminho_arquivo_excel (str): O caminho para o arquivo .xlsx.
    numero_cidades (int): O número de cidades a serem exibidas no ranking.
    """
    try:
        # --- Passo 1: Carregar os Dados do Arquivo Excel ---
        # Usamos pd.read_excel() para ler o arquivo.
        # 'header=2' informa que os nomes das colunas estão na terceira linha (índice 2).
        print(f"Carregando o arquivo Excel '{caminho_arquivo_excel}'...")
        df = pd.read_excel(caminho_arquivo_excel, header=2)
        print("Arquivo carregado com sucesso!")

        # --- Passo 2: Preparar os Dados ---
        # Seleciona a coluna 'Município' e todas as colunas de 'Colocação'.
        colunas_colocacao = [col for col in df.columns if 'Colocação' in col]
        df_ranking = df[['Município'] + colunas_colocacao].copy()

        # Garante que os valores de colocação sejam numéricos.
        for col in colunas_colocacao:
            df_ranking[col] = pd.to_numeric(df_ranking[col], errors='coerce')

        # --- Passo 3: Calcular a Pontuação ---
        # Soma as colocações para obter a pontuação final (menor é melhor).
        print("Calculando a pontuação de cada cidade...")
        df_ranking['Pontuacao_Final'] = df_ranking[colunas_colocacao].sum(axis=1)

        # Remove cidades que não puderam ter a pontuação calculada.
        df_ranking.dropna(subset=['Pontuacao_Final'], inplace=True)

        # --- Passo 4: Gerar e Exibir o Ranking ---
        # Ordena as cidades pela pontuação.
        df_ranking_final = df_ranking.sort_values(by='Pontuacao_Final').reset_index(drop=True)

        print("\n--- RANKING DAS MELHORES CIDADES PARA INVESTIR (TOP 33) ---")
        print("Baseado na soma das colocações em diversos indicadores.\n")

        # Exibe o resultado final com as 50 melhores.
        resultado = df_ranking_final[['Município', 'Pontuacao_Final']].head(numero_cidades)
        print(resultado)

    except FileNotFoundError:
        print(f"Erro: O arquivo '{caminho_arquivo_excel}' não foi encontrado!")
    except Exception as e:
        print(f"Ocorreu um erro inesperado: {e}")

# --- Execução do Programa ---
if __name__ == "__main__":
    # Coloque aqui o nome exato do seu arquivo Excel.
    nome_do_arquivo_excel = 'PROJETOdeinvestimento.xlsx'

    # Define o número de cidades para o ranking.
    top_n_cidades = 33

    # Chama a função para executar a análise.
    gerar_ranking_cidades_excel(nome_do_arquivo_excel, top_n_cidades)
# Out:
# Carregando o arquivo Excel 'PROJETOdeinvestimento.xlsx'...
# Arquivo carregado com sucesso!
# Calculando a pontuação de cada cidade...
#
# --- RANKING DAS MELHORES CIDADES PARA INVESTIR (TOP 33) ---
# Baseado na soma das colocações em diversos indicadores.
#
#                 Município  Pontuacao_Final
# 0      São Caetano do Sul             6419
# 1                 Jundiaí             7041
# 2                Campinas             7207
# 3                Paulínia             7390
# 4                  Santos             7486
# 5               São Paulo             7530
# 6                Botucatu             7589
# 7                 Maringá             7603
# 8              Indaiatuba             7627
# 9   São Bernardo do Campo             7671
# 10          Florianópolis             7704
# 11            Votuporanga             7758
# 12         Jaraguá do Sul             7871
# 13                Barueri             7882
# 14               Curitiba             7912
# 15                Vitória             8071
# 16     Balneário Camboriú             8073
# 17                Lajeado             8132
# 18                Pinhais             8165
# 19            Pato Branco             8264
# 20          São Sebastião             8296
# 21             Uberlândia             8336
# 22                 Toledo             8340
# 23             Piracicaba             8386
# 24               Barretos             8398
# 25               Criciúma             8423
# 26                Atibaia             8446
# 27              Joinville             8453
# 28        Poços de Caldas             8551
# 29  São João da Boa Vista             8604
# 30              Nova Lima             8639
# 31         Belo Horizonte             8655
# 32                 Franca             8672
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
